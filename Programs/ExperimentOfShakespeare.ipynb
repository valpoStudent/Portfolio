# %%
##### Using pip install to obtain the necessary modules to use
# !pip install --upgrade language_tool_python
# !pip install gingerit
# !pip install stanfordnlp
# !pip install nlpcloud
# Out:
# Requirement already satisfied: language_tool_python in /usr/local/lib/python3.10/dist-packages (2.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (3.4)
# Requirement already satisfied: gingerit in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: cloudscraper<2.0.0,>=1.2.66 in /usr/local/lib/python3.10/dist-packages (from gingerit) (1.2.71)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.10/dist-packages (from cloudscraper<2.0.0,>=1.2.66->gingerit) (3.1.0)
# Requirement already satisfied: requests>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from cloudscraper<2.0.0,>=1.2.66->gingerit) (2.27.1)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from cloudscraper<2.0.0,>=1.2.66->gingerit) (1.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.2->cloudscraper<2.0.0,>=1.2.66->gingerit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.2->cloudscraper<2.0.0,>=1.2.66->gingerit) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.2->cloudscraper<2.0.0,>=1.2.66->gingerit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.2->cloudscraper<2.0.0,>=1.2.66->gingerit) (3.4)
# Requirement already satisfied: stanfordnlp in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanfordnlp) (1.22.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from stanfordnlp) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanfordnlp) (2.27.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from stanfordnlp) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanfordnlp) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->stanfordnlp) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->stanfordnlp) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->stanfordnlp) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordnlp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordnlp) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordnlp) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordnlp) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->stanfordnlp) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->stanfordnlp) (1.3.0)
# Requirement already satisfied: nlpcloud in /usr/local/lib/python3.10/dist-packages (1.1.44)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nlpcloud) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nlpcloud) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nlpcloud) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->nlpcloud) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nlpcloud) (3.4)

# %%
import numpy
#import gensim
from gensim.models import Word2Vec
from zipfile import ZipFile
from collections import defaultdict
import random
import json
import nltk
import language_tool_python as lang
from gingerit.gingerit import GingerIt
import spacy
import stanfordnlp as stanNLP
nltk.download("averaged_perceptron_tagger")

import gensim.downloader
import nlpcloud
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
##print(gensim.downloader.info()['models'].keys())
anotherModel = gensim.downloader.load("glove-wiki-gigaword-100")  ##downloading a glove model
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
anotherModel.doesnt_match(['king','horatio','hamlet','macbeth','shakespeare'])  ##shows which word does not belong to a list
# Out:
# 'horatio'

# %%
# !wget "http://cslab.valpo.edu/~mglass/AllShakespeare.txt"  ## downloading the shakespearean text.
# Out:
# --2023-08-07 19:48:37--  http://cslab.valpo.edu/~mglass/AllShakespeare.txt
# Resolving cslab.valpo.edu (cslab.valpo.edu)... 152.228.81.102
# Connecting to cslab.valpo.edu (cslab.valpo.edu)|152.228.81.102|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5663512 (5.4M) [text/plain]
# Saving to: ‘AllShakespeare.txt’
#
# AllShakespeare.txt  100%[===================>]   5.40M  10.9MB/s    in 0.5s
#
# 2023-08-07 19:48:38 (10.9 MB/s) - ‘AllShakespeare.txt’ saved [5663512/5663512]

# %%
##### The punctuation variable is used to remove the punctuations in the corpus.
punct = '!"#$%&\'()*+,-./:;<=>?&[\\]~_`{|}~\u2018\u2019\u201c\u201d\u2014'

##### This method creates the corpus that will be used for n-grams. The file used to create the corpus is first read. This returns a list of lines that will be helpful in lowercasing each
##### line, replacing the em dash with the new line, and spliting the line. The line is then added to the temporary list and is checked to see if the length of the sentence is not zero.
##### If it is not, the list of lines will include the new line without any punctuations.
def nGramsCorpus(file):
  tempList = list()
  listOfLines = list()
  with open(file,encoding='UTF-8 SIG') as shakespeareFile:
    text = shakespeareFile.readlines()
  for line in text:
    tempList.append(line.lower().replace("\u2014","\n").split())
  for sentence in tempList:
    if(len(sentence) != 0):
      newSentence = [word.strip(punct) for word in sentence]
      listOfLines.append(newSentence)
  return listOfLines

##### This method adds the sentence markers ("<s>" and "</s>") to each line. The another
##### list will append the line. It returns the list that contains lines with sentence markers.
def addSentenceMarkers(textToAddMarkers):
  finalList = list()
  for line in textToAddMarkers:
    line.insert(0,"<s>")
    line.insert(len(line),"</s>")
    finalList.append(line)
  return finalList

##### This will count the number of unigrams in the text. It returns the unigram dictionary where it details the word and the number of times the word appears.
def unigram_count(text):
  unigram_dict = defaultdict(int)
  for sentence in text:
    for term in sentence:
      unigram_dict[term] += 1
  return unigram_dict

##### This will count the number of bigrams in the text. It returns the bigram dictionary, which contains the phrase with two words and the total number of appearances of the phrases.
def bigram_count(unigram,text):
  bigram_dict = dict([(word,defaultdict(int)) for word in unigram])
  for sentence in text:
    for index in range(len(sentence)-1):
      firstWord = sentence[index]
      secondWord = sentence[index+1]
      bigram_dict[firstWord][secondWord] += 1
  return bigram_dict

##### This will count the number of trigrams in the text. It will return the trigram dictionary with the phrase of three words and the number of its appearances in the corpus.
##### Unlike the other two methods, the trigram count method uses the for-loop to create a default dictionary for each three-word phrase.
def trigram_count(unigram,bigram,text):
  trigram_dict = {}
  for word in unigram:
    trigram_dict[word] = {}
    for second_words in bigram[word]:
      trigram_dict[word][second_words] = defaultdict(int)
  for line in text:
    for i in range(len(line)-2):
      first_word = line[i]
      second_word = line[i+1]
      third_word = line[i+2]
      trigram_dict[first_word][second_word][third_word] += 1
  return trigram_dict

##### This determines the next word based on the last word. First, the goal number is picked between the range of one and the total number of times where the word appears.
##### The for-loop is used to add the count to the index and determine if the index is greater or equal to the goal number. If it is, it will return a word.
def bigram_next_word(unigram,bigram,word): ## based on Shakespeare bigram generator
  total_number = unigram[word]
  goal_number = random.randint(1,total_number)
  index = 0
  for w,c in bigram[word].items():
    index += c
    if(index >= goal_number):
      return w

##### This will generate bigrams and returns a line based on the bigrams.
def generate_bigram(u,b):
  line = ["<s>"]
  while(line[-1] != "</s>"):
    nextWord = bigram_next_word(u,b,line[-1])
    line.append(nextWord)
  return line

##### This "predicts" the next word according to the previous two words. Similar to the bigram next word method,
##### it will select a random integer as the goal number. Once the index reaches to the goal number (or exceeds it), the method
##### will return a word.
def trigram_next_word(bigramDict,triDict,word,word2):
  total = bigramDict[word][word2]
  goal = random.randint(1,total)
  index = 0
  for w,c in triDict[word][word2].items():
    index += c
    if (index >= goal):
      return w

##### This will produce trigrams and return a sentence.
def generate_trigram(unigramDict,bigramDict,triDict):
  line = ["<s>"]
  while(line[-1] != "</s>"):
    if(len(line)<2):
      secondWord = bigram_next_word(unigramDict,bigramDict,line[-1])
      line.append(secondWord)
    thirdWord = trigram_next_word(bigramDict,triDict,line[-2],line[-1])
    line.append(thirdWord)
  return line

random.seed('shakespeare')

nGramCorpus = nGramsCorpus('AllShakespeare.txt')
nGramCorpus = addSentenceMarkers(nGramCorpus)

unigram = unigram_count(nGramCorpus)
bigram = bigram_count(unigram, nGramCorpus)
trigram = trigram_count(unigram,bigram,nGramCorpus)

##print(trigram_next_word(bigram,trigram,'means','your'))

print("Trigram")
for i in range(30):
  print(" ".join(generate_trigram(unigram,bigram,trigram)))
print()
print("Bigram")
for i in range(30):
  print(" ".join(generate_bigram(unigram,bigram)))
# Out:
# Trigram
# <s> as i am today i th’vein of chivalry </s>
# <s> if you be safer </s>
# <s> then to thee </s>
# <s> how now a wood near athens </s>
# <s> lear </s>
# <s> therefore to our rose of youth </s>
# <s> exeunt </s>
# <s> a dangerous law against it </s>
# <s> in any case not that their first of manhood stand upright </s>
# <s> subdu’d me </s>
# <s> great timon noble worthy royal timon </s>
# <s> cinna             4d </s>
# <s> ever true in me else </s>
# <s> what would come against us like the heaven's glorious sun </s>
# <s> warwick </s>
# <s> that i will proclaim you out </s>
# <s> pass with a hovel </s>
# <s> jessica </s>
# <s> i’ll help it now appears you need not be </s>
# <s> tis true </s>
# <s> enter the two or three servants </s>
# <s> the devil his true tears all bewet </s>
# <s> finds bottom in th’uncomprehensive deeps </s>
# <s> we laugh say when i told you sir dost know this and dwell upon your brows </s>
# <s> i mean of us o tell me john hath reconcil’d </s>
# <s> york </s>
# <s> so i know thee to be most reverend signior do you mean </s>
# <s> can be </s>
# <s> edgar </s>
# <s> therefore i pray you go back one foot to the sagittary </s>
#
# Bigram
# <s> king and join with that wear my gracious duke what is missing of man's nature what cloten’s head </s>
# <s> i know me like to heaven is stopp’d </s>
# <s> touchstone </s>
# <s> why that the officers do t </s>
# <s> nay i tallies thy knife </s>
# <s> of ye rude beast and made </s>
# <s> philostrate lords bow </s>
# <s> come to give me i bear them down at ninny’s tomb the hope of the accused them will not afraid sir come boy go </s>
# <s> pistol </s>
# <s> i may then all that lives my father and of wine </s>
# <s> signior </s>
# <s> the hound but answer join gripes of your bed which makes of ephesus </s>
# <s> for beauty stirs next it shall seek out of disposition is that swear them </s>
# <s> imogen </s>
# <s> as recompense of france to tell you </s>
# <s> for our host and i prithee have besides he doth sin again in this audience but am too short and knowledge with anger cassio </s>
# <s> mine mine sir andrew aguecheek </s>
# <s> first begin at an honest flaminius your wanting that do i would buy spices ink paper there is now sir in this grow there is not so have not think it </s>
# <s> clerk-like experienc’d which in court where he cannot be the body should deny </s>
# <s> and they whirl along </s>
# <s> exeunt </s>
# <s> shall be to dream </s>
# <s> kind sir you </s>
# <s> his guard it a </s>
# <s> upon the rein his offence be content </s>
# <s> than i but here on mere falsehood she had all </s>
# <s> of the sourest-natured dog a couch no swaggerers i can think your king </s>
# <s> to </s>
# <s> george </s>
# <s> cardinal </s>

# %%
##punct = '!"#$%&\'()*+,-./:;<=>?&[\\]~_`{|}~\u2018\u2019\u201c\u201d\u2014'

##### This method is commented out since the nGramsCorpus method is also a viable option of creating the corpus with the improved sentences. This method is similar
##### to the previous method nGramsCorpus.
##def nGramsCorpusWithImprovedText(fileWithImprovedText):
  ##temporaryList = list()
  ##listOfSentences = list()
  ##with open(fileWithImprovedText,encoding="UTF-8") as file:
  ##  lineList = file.readlines()
  ##for line in lineList:
  ##  line = line.lower().strip().strip(punct).replace("\u2014","\n").split()
  ##  temporaryList.append(line)
  ##for sentence in temporaryList:
  ##  newSentence = [word.strip(punct) for word in sentence]
  ##  listOfSentences.append(newSentence)
  ##return listOfSentences

##### This will print out the generated trigrams and screen out the trigrams with words less than 3.
def printingTrigrams(unigram,bigram,trigram,iterations):
  lineList = list()
  for i in range(iterations):
    trigramLine = generate_trigram(unigram,bigram,trigram)
    if(len(trigramLine) == 3):
      while(len(trigramLine)==3):
        trigramLine = generate_trigram(unigram,bigram,trigram)
    lineList.append(trigramLine)
    print(trigramLine)
  ##return lineList

improvedShakespeareText = nGramsCorpus("ShakespeareSentences.txt")
improvedShakespeareText = addSentenceMarkers(improvedShakespeareText)
newUnigram = unigram_count(improvedShakespeareText)
newBigram = bigram_count(newUnigram,improvedShakespeareText)
newTrigram = trigram_count(newUnigram, newBigram, improvedShakespeareText)

random.seed('romeo and juliet')
print("###New Trigram#####")
printingTrigrams(newUnigram,newBigram,newTrigram,10)
# Out:
# ###New Trigram#####
# ['<s>', 'she', 'eat', 'no', 'more', '</s>']
# ['<s>', 'send', 'me', 'to', 'see’t', '</s>']
# ['<s>', 'he', 'loves', 'caesar', '</s>']
# ['<s>', 'are', 'you', 'not', 'heard', 'from', 'him', '</s>']
# ['<s>', 'go', 'to', 'bed', 'after', 'midnight', '</s>']
# ['<s>', 'camp', 'of', 'the', 'king', 'as', 'i', 'would', 'cudgel', 'him', 'and', 'he', 'beseech’d', 'me', 'to', 'my', 'affection', 'so', 'far', 'deceived', 'in', 'him', 'master', 'of', 'fence-three', 'veneys', 'for', 'a', 'while', 'what', 'will', 'it', 'would', 'be', 'here', 'though', 'thou', 'stand’st', 'a', 'breathing', '</s>']
# ['<s>', 'heaven', 'that', 'henry’s', 'dead', '</s>']
# ['<s>', 'henry', 'the', 'fifth', 'attended', 'on', 'by', 'night', 'unseen', 'yet', 'crescive', 'in', 'his', 'monarchy', '</s>']
# ['<s>', 'therefore', 'another', 'prologue', 'must', 'tell', 'thee', 'daughter', 'for', 'a', 'pad', 'conscience', '</s>']
# ['<s>', 'i', 'trust', 'shall', 'witness', 'live', 'in', 'your', 'weakness', 'strength', 'unto', 'your', "ladyship's", 'command', '</s>']

# %%
random.seed("shakespeare")

sentence = generate_trigram(unigram,bigram,trigram)
print(sentence)
print(nltk.pos_tag(sentence[1:-1]))

for w in sentence[1:-1]:
  print(nltk.pos_tag([w]))
# Out:
# ['<s>', 'as', 'i', 'am', 'today', 'i', 'th’vein', 'of', 'chivalry', '</s>']
# [('as', 'IN'), ('i', 'NN'), ('am', 'VBP'), ('today', 'NN'), ('i', 'JJ'), ('th’vein', 'NN'), ('of', 'IN'), ('chivalry', 'NN')]
# [('as', 'IN')]
# [('i', 'NN')]
# [('am', 'VBP')]
# [('today', 'NN')]
# [('i', 'NN')]
# [('th’vein', 'NN')]
# [('of', 'IN')]
# [('chivalry', 'NN')]

# %%
corpusModel = gensim.models.Word2Vec(nGramCorpus)

# %%
sonnetCorpus = nGramsCorpus('sonnets.txt')
sonnetCorpus = addSentenceMarkers(sonnetCorpus)
sonnetModel = gensim.models.Word2Vec(sonnetCorpus)

sonnetModel.wv.most_similar('rose')
# Out:
# [('whose', 0.9954397082328796),
#  ('she', 0.9953383803367615),
#  ('my', 0.9952844977378845),
#  ('black', 0.9951425194740295),
#  ('their', 0.9951171278953552),
#  ('so', 0.9951009154319763),
#  ('one', 0.9950540661811829),
#  ('before', 0.9949631690979004),
#  ('no', 0.9949607253074646),
#  ('in', 0.9949582815170288)]

# %%
random.seed('shakespeare')

##### This displays the possible words based on the random word chosen. If the Word2Vec model does not have the random-selected word, it
##### might either examine if the Word2Vec model contains keyed vectors. If it does not, the method might resort to use the "error message."
##### The method uses the nltk pos-tagger to classify each word's part of speech from the list produced by the Word2Vec. If the current part
##### of speech matches to the target one, the word will be included to the list of words. The method overall returns a tuple of the list of words, target word, target part of speech,
##### the random index, and the list of likely words from the Word2Vec.
def generatePossibleWords(sent,W2Vmodel):
  randomInt = random.randint(1,len(sent)-2)
  target_POS = nltk.pos_tag(sent)[randomInt][1]
  target_w = sent[randomInt] ## use the try-except method
  try:
    likely_replace = W2Vmodel.wv.most_similar([target_w],topn=15)
  except:
    if(isinstance(W2Vmodel,gensim.models.KeyedVectors)==True): ## checks if the model is a keyed-vector
      likely_replace = W2Vmodel.most_similar([target_w],topn=15)
    else:
      likely_replace = [('Error',0.0)]
      print(f"Word in concern: {target_w}")
  list_words = list()
  for possible_word,similarity in likely_replace:
    pw_POS = nltk.pos_tag([possible_word])[0][1]
    if(pw_POS == target_POS):
      list_words.append(possible_word)
  return list_words,target_w,target_POS,randomInt,likely_replace

##print(sentence)

for i in range(1,100,10):
  sentence = nGramCorpus[i]
  if(len(sentence) > 3):
    print(nGramCorpus[i],generatePossibleWords(nGramCorpus[i],anotherModel))

print()

for i in range(1,100,10):
  s = nGramCorpus[i]
  if (len(s)>3):
    print(s,generatePossibleWords(s,corpusModel))

print()

for i in range(1,100,10):
  s = nGramCorpus[i]
  if(len(s)>3):
    print(s,generatePossibleWords(s,sonnetModel))

##print(generatePossibleWords(sentence,corpusModel))
##print(generatePossibleWords(nGramCorpus[14],corpusModel))
##print(f"Sentence: {nGramCorpus[14]}")
# Out:
# ['<s>', 'and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring', '</s>'] (['this', 'another', 'both', 'all'], 'the', 'DT', 5, [('this', 0.8573122024536133), ('part', 0.8507951498031616), ('one', 0.8503074049949646), ('of', 0.8328992128372192), ('same', 0.8324545621871948), ('first', 0.8210473656654358), ('on', 0.8199756741523743), ('its', 0.8169469237327576), ('as', 0.8128418922424316), ('that', 0.8079659938812256), ('another', 0.8061550259590149), ('it', 0.804827094078064), ('both', 0.8008524775505066), ('time', 0.8005280494689941), ('all', 0.7978261709213257)])
# ['<s>', 'then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies', '</s>'] (['when'], 'where', 'WRB', 4, [('.', 0.8364126682281494), ('now', 0.8304319977760315), ('there', 0.826165497303009), ('when', 0.8133443593978882), ('once', 0.8115141987800598), ('it', 0.8035557866096497), ('one', 0.8034142851829529), ('which', 0.8012702465057373), ('well', 0.7950435876846313), ('they', 0.7896511554718018), ('but', 0.7889991998672485), ('that', 0.7872189283370972), ('still', 0.7870111465454102), ('then', 0.7869663834571838), ('though', 0.7852042317390442)])
# ['<s>', 'calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime', '</s>'] ([], 'back', 'RP', 2, [('away', 0.8724468350410461), ('out', 0.8683187961578369), ('off', 0.8472046256065369), ('again', 0.8431844115257263), ('up', 0.8425763845443726), ('into', 0.8356085419654846), ('down', 0.8321743607521057), ('coming', 0.828819751739502), ('put', 0.8255141973495483), ('went', 0.8248604536056519), ('came', 0.8195070624351501), ('go', 0.8170133829116821), ('left', 0.8155544996261597), ('going', 0.8121851682662964), ('come', 0.8091155886650085)])
# ['<s>', 'then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse', '</s>'] (['again', 'finally', 'later', 'once', 'eventually', 'soon', 'instead'], 'then', 'RB', 1, [('when', 0.8950532078742981), ('again', 0.869105339050293), ('finally', 0.8576523661613464), ('before', 0.8562531471252441), ('later', 0.8558248281478882), ('he', 0.8466284871101379), ('once', 0.8435139060020447), ('eventually', 0.827532172203064), ('came', 0.8245142102241516), ('soon', 0.8197597861289978), ('instead', 0.8112487196922302), ('went', 0.8102326989173889), ('turned', 0.8054001331329346), ('turn', 0.8051618933677673), ('it', 0.8041524291038513)])
# ['<s>', 'a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass', '</s>'] (['another', 'an', 'this', 'the'], 'a', 'DT', 1, [('another', 0.9156777262687683), ('one', 0.8415572643280029), ('an', 0.8172469735145569), ('this', 0.8091385960578918), ('same', 0.7917115688323975), ('only', 0.7776665687561035), ('the', 0.7759782075881958), ('as', 0.7728384733200073), ('first', 0.7711368203163147), ('is', 0.7670686841011047), ('with', 0.7621939778327942), ('last', 0.7480362057685852), ('part', 0.7454843521118164), ('it', 0.7443710565567017), ('for', 0.7428671717643738)])
# ['<s>', 'that', 'use', 'is', 'not', 'forbidden', 'usury', '</s>'] ([], 'forbidden', 'JJ', 5, [('prohibited', 0.7181296944618225), ('permitted', 0.6509078741073608), ('strictly', 0.619401752948761), ('banned', 0.6039126515388489), ('forbid', 0.600328266620636), ('sacred', 0.5972364544868469), ('worship', 0.5498632192611694), ('forbade', 0.5482013821601868), ('restricted', 0.5458968281745911), ('forbidding', 0.5430938005447388), ('taboo', 0.5405327677726746), ('purposes', 0.5296735167503357), ('banning', 0.5272707343101501), ('secret', 0.5269578099250793), ('forbids', 0.5265270471572876)])
#
# ['<s>', 'and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring', '</s>'] (['top', 'flame', 'shade', 'root', 'flight', 'forfeit', 'seat', 'smoke', 'conquest', 'forehead', 'height', 'view'], 'spring', 'NN', 7, [('top', 0.9393402934074402), ('bowels', 0.938292384147644), ('ashes', 0.9340448379516602), ('temples', 0.9327806234359741), ('flame', 0.931797444820404), ('shade', 0.9219171404838562), ('root', 0.9203269481658936), ('flight', 0.9197424054145813), ('forfeit', 0.9185658097267151), ('seat', 0.9168863296508789), ('smoke', 0.9167113900184631), ('conquest', 0.9153467416763306), ('forehead', 0.9151193499565125), ('height', 0.9138813018798828), ('view', 0.9131991267204285)])
# ['<s>', 'then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies', '</s>'] (['comes', 'goes', 'is', 'seems', 'appears', 'holds'], 'lies', 'VBZ', 8, [('stands', 0.9402283430099487), ('comes', 0.8406739830970764), ('goes', 0.7931950688362122), ('is', 0.7915727496147156), ('grows', 0.7706934213638306), ('seems', 0.7668484449386597), ('dies', 0.7501105666160583), ('lodges', 0.7460748553276062), ('appears', 0.7442045211791992), ('lo', 0.7433325052261353), ('bears', 0.73828125), ('holds', 0.7328701019287109), ('who’s', 0.7314915060997009), ('begins', 0.725121021270752), ('sits', 0.7202973365783691)])
# ['<s>', 'calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime', '</s>'] (['infectious', 'grand'], 'prime', 'JJ', 8, [('malady', 0.9382377862930298), ('plots', 0.9342387318611145), ('worthiest', 0.932597279548645), ('slanders', 0.9322667121887207), ('syria', 0.9289277791976929), ('infectious', 0.926632821559906), ('breathing', 0.92662113904953), ('grand', 0.9264839291572571), ('reports', 0.926098108291626), ('patch', 0.9248300194740295), ('becoming', 0.9247289896011353), ('household', 0.9246784448623657), ('lawless', 0.9240497350692749), ('steps', 0.9240353107452393), ('rascals', 0.9235323667526245)])
# ['<s>', 'then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse', '</s>'] (['empty', 'envious'], 'beauteous', 'JJ', 2, [('empty', 0.9440574049949646), ('entrails', 0.938764214515686), ('fierce', 0.9358714818954468), ('youthful', 0.9346601963043213), ('insurrection', 0.9336732029914856), ('cloth', 0.9333244562149048), ('qualities', 0.9322643876075745), ('bastardy', 0.930059015750885), ('ken', 0.928838312625885), ('delicate', 0.92698734998703), ('alcides', 0.9269676804542542), ('searching', 0.9260440468788147), ('plate', 0.9259442687034607), ('nerves', 0.9258509278297424), ('envious', 0.925834596157074)])
# ['<s>', 'a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass', '</s>'] ([], 'liquid', 'JJ', 2, [('obscure', 0.9628856182098389), ('eyeless', 0.9474745988845825), ('solace', 0.9461008906364441), ('sleeves', 0.9457594752311707), ("heaven's", 0.9455922245979309), ('lamenting', 0.9451079368591309), ('jove’s', 0.9450154304504395), ('for’s', 0.9447935819625854), ('vast', 0.9444177150726318), ('basin', 0.9443413019180298), ('convert', 0.9437348246574402), ('eager', 0.9431670904159546), ('graceful', 0.942956805229187), ('mounting', 0.9422075152397156), ('support', 0.941988468170166)])
# ['<s>', 'that', 'use', 'is', 'not', 'forbidden', 'usury', '</s>'] (['seems', 'comes', 'has', 'says', 'makes'], 'is', 'VBZ', 3, [('lies', 0.7915727496147156), ('stands', 0.7590599060058594), ('was', 0.7575271725654602), ('seems', 0.7430884838104248), ('that’s', 0.7052244544029236), ('comes', 0.7002012729644775), ('has', 0.6862249970436096), ('tis', 0.68021559715271), ('speaks', 0.6796717643737793), ('bears', 0.6651296615600586), ('grows', 0.6619308590888977), ('what’s', 0.660435140132904), ('says', 0.6602111458778381), ('makes', 0.6573588848114014), ('knows', 0.6536896824836731)])
#
# ['<s>', 'and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring', '</s>'] (['lie', 'tell', 'dost', 'nature'], 'spring', 'NN', 7, [('up', 0.9839034676551819), ('he', 0.9831290245056152), ('lie', 0.9831158518791199), ('tell', 0.9829606413841248), ('better', 0.9829103350639343), ('dost', 0.9826961159706116), ('did', 0.9826546311378479), ('words', 0.982616662979126), ('where', 0.9825705289840698), ('them', 0.9825167059898376), ('eyes', 0.9825167059898376), ('for', 0.9825122952461243), ('nature', 0.9824905395507812), ('hours', 0.982472836971283), ('who', 0.9824156761169434)])
# ['<s>', 'then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies', '</s>'] (['a', 'the'], 'all', 'DT', 5, [('</s>', 0.9993976354598999), ('thy', 0.9993797540664673), ('a', 0.9993582963943481), ('what', 0.99934321641922), ('from', 0.9993401765823364), ('and', 0.9993316531181335), ('<s>', 0.9993299841880798), ('her', 0.9993271827697754), ('my', 0.9993234872817993), ('the', 0.9993055462837219), ('that', 0.9993042349815369), ('i', 0.9993035197257996), ('of', 0.9993026256561279), ('how', 0.9992936849594116), ('thou', 0.9992884397506714)])
# ['<s>', 'calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime', '</s>'] ([], 'back', 'RP', 2, [('which', 0.9970491528511047), ('not', 0.9970391988754272), ('as', 0.9970159530639648), ('that', 0.997008740901947), ('do', 0.9968870878219604), ('was', 0.9967747926712036), ('</s>', 0.9967728853225708), ('doth', 0.9967615604400635), ('what', 0.9967547655105591), ('should', 0.9967374801635742), ('of', 0.9967345595359802), ('love', 0.9967309236526489), ('then', 0.9967294335365295), ('thou', 0.9967274069786072), ('she', 0.9967151284217834)])
# ['<s>', 'then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse', '</s>'] ([], 'then', 'RB', 1, [('his', 0.9994840025901794), ('</s>', 0.9994468092918396), ('from', 0.9994372725486755), ('with', 0.9993798732757568), ('to', 0.999377965927124), ('a', 0.9993758201599121), ('that', 0.999351978302002), ('my', 0.9993324279785156), ('what', 0.9993206262588501), ('your', 0.9993125796318054), ('as', 0.9993100762367249), ('or', 0.999296247959137), ('and', 0.9992920756340027), ('it', 0.9992871880531311), ('<s>', 0.9992846846580505)])
# Word in concern: pent
# ['<s>', 'a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass', '</s>'] (['Error'], 'pent', 'NN', 4, [('Error', 0.0)])
# ['<s>', 'that', 'use', 'is', 'not', 'forbidden', 'usury', '</s>'] (['yet'], 'not', 'RB', 4, [('</s>', 0.9994679689407349), ('<s>', 0.9993651509284973), ('be', 0.9993575811386108), ('i', 0.9993553161621094), ('and', 0.9993404150009155), ('thou', 0.9993376731872559), ('thee', 0.9993293881416321), ('that', 0.9993194341659546), ('to', 0.9993187189102173), ('his', 0.9993045926094055), ('thy', 0.9992886781692505), ('in', 0.9992876052856445), ('my', 0.9992755055427551), ('yet', 0.9992683529853821), ('a', 0.9992663860321045)])

# %%
##### The first three lists contains conjunctions (mostly) and auxillary verbs. The auxilary verbs are used to examine if there is an inconsistency between the next word and the auxilary verb.
##### The stop words, on the other hand, are useful in not allowing the code to alter them. It is also helpful to prevent the code from altering the shakespearean pronouns
##### (if the downloaded Python library did not classify them as stop words).
stop_words = [ "a", "about", "above", "after", "again", "against", "all", "am", "an",
"and", "any", "are", "as", "at", "be", "because", "been", "before",
"being", "below", "between", "both", "but", "by", "could", "did", "do",
"does", "doing", "down", "during", "dost", "doth", "each", "few", "for", "from",
"further", "had", "has", "hast", "have", "having", "he", "he'd", "he'll",
"he's", "her", "here", "here's", "hers", "herself", "him", "himself",
"his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in",
"into", "is", "it", "it's", "its", "itself", "let's", "me", "more",
"most", "my", "myself", "nor", "of", "on", "once", "only", "or",
"other", "ought", "our", "ours", "ourselves", "out", "over", "own",
"same", "she", "she'd", "she'll", "she's", "should", "so", "some",
"such", "than", "that", "that's", "the", "thee", "their", "theirs", "them",
"themselves", "then", "there", "there's", "these", "they", "they'd",
"they'll", "they're", "they've", "thine", "this", "those", "thou", "through", "thy", "thyself", "to",
"too", "under", "until", "up", "very", "was", "we", "we'd", "we'll",
"we're", "we've", "were", "what", "what's", "when", "when's", "where",
"where's", "which", "while", "who", "who's", "whom", "why", "why's",
"with", "would", "ye", "you", "you'd", "you'll", "you're", "you've", "your",
"yours", "yourself", "yourselves" ]

modal_verbs = ["must","shall","will","should","would","can","could","may","might"]

primary_aux_verbs = ['have','be','do']

print(nltk.pos_tag(['ate']))
print(nltk.pos_tag(['meal']))
nltk.pos_tag(['i','ate','lunch','yesterday'])

##stanNLP.download('en_ewt')
nlp = spacy.load("en_core_web_sm")
##POSChecker = stanNLP.Pipeline()

##document = POSChecker("My home lies over the ocean.")

##document.sentences[0].print_dependencies()

##client = nlpcloud.Client("My home lies over the ocean.")
##client.sentence_dependencies

##grammarCheck = lang.LanguageTool("en-US",config={'maxTextLength':150,'cacheSize':1000,'pipelineCaching':True})
##sentenceChecker = GingerIt()

##sentenceChecker.parse("the brown fox chickens some eggs")

##def replace_certain_word():
  ##l = "l"
# Out:
# [('ate', 'NN')]
# [('meal', 'NN')]

# %%
grammarCheck = lang.LanguageTool("en-US",config={'maxTextLength':150,'cacheSize':1000,'pipelineCaching':True})
# Out:
# Downloading LanguageTool 5.7: 100%|██████████| 225M/225M [00:03<00:00, 71.8MB/s]
# INFO:language_tool_python.download_lt:Unzipping /tmp/tmpxakecjbm.zip to /root/.cache/language_tool_python.
# INFO:language_tool_python.download_lt:Downloaded https://www.languagetool.org/download/LanguageTool-5.7.zip to /root/.cache/language_tool_python.

# %%
gingerCheck = GingerIt()
corrections1 = gingerCheck.parse("you do not laughed")
print(corrections1)
corrections2 = gingerCheck.parse("hence you must sleep")
print(corrections2['corrections'][0])
###grammarCheck.correct("therefore commitment of perfect’st love being made")
# Out:
# {'text': 'you do not laughed', 'result': 'you do not laugh', 'corrections': [{'start': 4, 'text': 'do not laughed', 'correct': 'do not laugh', 'definition': None}]}
# {'start': 0, 'text': 'hence you', 'correct': 'Hence, you', 'definition': 'Accept comma addition'}

# %%
##sentenceChecker.parse("The brown fox meal some chicken.")
nlp = spacy.load("en_core_web_sm")
results = nlp("The brown fox chicken some chicken.")
##for word in results:
  ##print(word,word.pos_,word.dep_,word.tag_)

##### Creating a word substitution method ########

##### This method will swap (or replace) the old word to the newer version of the word, which is randomly selected. It is recommended to use the list version of the document.
def word_swap(wordList,sentenceInConcern,trueIndex):
  rand_index = random.randint(0,len(wordList)-1)
  rand_word = wordList[rand_index]
  print(f'word in concern: {rand_word}\n')
  sentenceInConcern.pop(trueIndex)
  sentenceInConcern.insert(trueIndex,rand_word)


###### Using the spacy method ########
random.seed(1)

##### This determines the part of speech on a randomly-selected word from the sentence.
##### It returns the part of speech of the word based on context.
def insert_delete(wordArray,indexInConcern,word):
  ##print(f"Initial: {wordArray}")
  wordArray.pop(indexInConcern)
  ##print(f"With word removed: {wordArray}")
  wordArray.insert(indexInConcern,word)
  ##print(f"With new word inserted: {wordArray}")
  current_Pos = nlp(" ".join(wordArray))[indexInConcern].tag_   ##+1].tag_
  ##parsedSentence = nlp(" ".join(wordArray))
  ##for token in parsedSentence:
    ##print(f"Parsing the sentence : {token,token.tag_,parsedSentence}")
  return current_Pos

sentencesList = list()
#### Using the Shakespearean corpus ####
for index in range(1,100,10):
  testSentence = nGramCorpus[index]
  if (len(testSentence)!=3):
    sentence2 = testSentence[1:-1].copy()
    sentString = " ".join(sentence2)
    doc = nlp(sentString)
    docList = [str(w) for w in doc]
    stopWordCount = 0
    for token in doc:
      print(token,token.is_stop)
      if(token.is_stop or stop_words.count(str(token))!=0):
        stopWordCount+=1
    nonStopWordsCount = len(doc) - stopWordCount
    print(stopWordCount)
    wordsUsed = []
    for i in range(nonStopWordsCount):
      randInt = random.randint(0,len(doc)-1) ##1,len(testSentence)-2)
      wordInConcern = doc[randInt]        ##'sun'   ##testSentence[randInt]
      isStopWord = wordInConcern.is_stop  ####nlp(wordInConcern)[0].is_stop
      wordsUsed.append(wordInConcern)
      print(f"Debugging process: {wordInConcern,isStopWord,wordsUsed,sentence2}")
      if(isStopWord==True or wordsUsed.count(wordInConcern)>=2 or stop_words.count(str(wordInConcern))!=0):
        while(isStopWord==True or wordsUsed.count(wordInConcern)>=2 or stop_words.count(str(wordInConcern))!=0):
          randInt = random.randint(0,len(doc)-1)  ##1,len(testSentence)-2)
          wordInConcern = doc[randInt] ##testSentence[randInt]
          isStopWord = wordInConcern.is_stop  ##nlp(wordInConcern)[0].is_stop
          wordsUsed.append(wordInConcern)
          print(f"Random number, word in concern, is_stop_word: {randInt,wordInConcern,isStopWord,wordsUsed}")
      posInConcern = nlp(sentString)[randInt].tag_  ##randInt-1].tag_
      for i in range(len(nlp(sentString))):
        print(f"Result sentence:{nlp(sentString)[i].tag_,nlp(sentString)[i]}")
      print(f"Does this Word2Vec model have this word?  {corpusModel.wv.key_to_index.get(str(wordInConcern))!=None}")
      if(corpusModel.wv.key_to_index.get(str(wordInConcern))!=None):
        listOfPossibleWAndSim = corpusModel.wv.most_similar([str(wordInConcern)],topn=20)
        testList = list()
        for w,s in listOfPossibleWAndSim:
          currentPOS=insert_delete(docList,randInt,w) ##randInt,w)
          print(f"POS:{docList,currentPOS,w}")
          if (currentPOS == posInConcern):
            testList.append(w)
        print(posInConcern,wordInConcern)
        print(f"List 2: {testList}\n")
        if(len(testList)!=0):
          word_swap(testList,docList,randInt)   ##randInt-1)
          sentString = " ".join(docList)
    sentencesList.append(sentString)

print("\n\nResults")
for sentence in sentencesList:
  print(sentence)
# Out:
# and True
# only True
# herald False
# to True
# the True
# gaudy False
# spring False
# 4
# Debugging process: (only, True, [only], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Random number, word in concern, is_stop_word: (4, the, True, [only, the])
# Random number, word in concern, is_stop_word: (6, spring, False, [only, the, spring])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', herald)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('JJ', gaudy)
# Result sentence:('NN', spring)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'top'], 'NN', 'top')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'bowels'], 'NNS', 'bowels')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'ashes'], 'NNS', 'ashes')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'temples'], 'NNS', 'temples')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'flame'], 'NN', 'flame')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'shade'], 'NN', 'shade')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'root'], 'NN', 'root')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'flight'], 'NN', 'flight')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'forfeit'], 'NNP', 'forfeit')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'seat'], 'NN', 'seat')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'smoke'], 'NN', 'smoke')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'conquest'], 'NNP', 'conquest')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'forehead'], 'NNP', 'forehead')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'height'], 'NN', 'height')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'view'], 'NN', 'view')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'altar'], 'NN', 'altar')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'womb'], 'NN', 'womb')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'corpse'], 'NN', 'corpse')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'liking'], 'VBG', 'liking')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'limbs'], 'NNS', 'limbs')
# NN spring
# List 2: ['top', 'flame', 'shade', 'root', 'flight', 'seat', 'smoke', 'height', 'view', 'altar', 'womb', 'corpse']
#
# word in concern: flame
#
# Debugging process: (herald, False, [only, the, spring, herald], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', herald)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('JJ', gaudy)
# Result sentence:('NN', flame)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'groom', 'to', 'the', 'gaudy', 'flame'], 'VB', 'groom')
# POS:(['and', 'only', 'soothsayer', 'to', 'the', 'gaudy', 'flame'], 'NN', 'soothsayer')
# POS:(['and', 'only', 'puck', 'to', 'the', 'gaudy', 'flame'], 'NN', 'puck')
# POS:(['and', 'only', 'maide', 'to', 'the', 'gaudy', 'flame'], 'NN', 'maide')
# POS:(['and', 'only', 'text', 'to', 'the', 'gaudy', 'flame'], 'NN', 'text')
# POS:(['and', 'only', 'butcher', 'to', 'the', 'gaudy', 'flame'], 'NN', 'butcher')
# POS:(['and', 'only', 'ghost', 'to', 'the', 'gaudy', 'flame'], 'NN', 'ghost')
# POS:(['and', 'only', 'bottom', 'to', 'the', 'gaudy', 'flame'], 'NN', 'bottom')
# POS:(['and', 'only', 'executioner', 'to', 'the', 'gaudy', 'flame'], 'NN', 'executioner')
# POS:(['and', 'only', 'messenger', 'to', 'the', 'gaudy', 'flame'], 'NN', 'messenger')
# POS:(['and', 'only', 'dish', 'to', 'the', 'gaudy', 'flame'], 'VB', 'dish')
# POS:(['and', 'only', 'follower', 'to', 'the', 'gaudy', 'flame'], 'NN', 'follower')
# POS:(['and', 'only', 'flower', 'to', 'the', 'gaudy', 'flame'], 'VB', 'flower')
# POS:(['and', 'only', 'calf', 'to', 'the', 'gaudy', 'flame'], 'NN', 'calf')
# POS:(['and', 'only', 'troop', 'to', 'the', 'gaudy', 'flame'], 'NN', 'troop')
# POS:(['and', 'only', 'prologue', 'to', 'the', 'gaudy', 'flame'], 'VB', 'prologue')
# POS:(['and', 'only', 'hey', 'to', 'the', 'gaudy', 'flame'], 'UH', 'hey')
# POS:(['and', 'only', 'velvet', 'to', 'the', 'gaudy', 'flame'], 'NN', 'velvet')
# POS:(['and', 'only', 'keeper', 'to', 'the', 'gaudy', 'flame'], 'NN', 'keeper')
# POS:(['and', 'only', 'huntsman', 'to', 'the', 'gaudy', 'flame'], 'NN', 'huntsman')
# VB herald
# List 2: ['groom', 'dish', 'flower', 'prologue']
#
# word in concern: groom
#
# Debugging process: (to, True, [only, the, spring, herald, to], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Random number, word in concern, is_stop_word: (6, spring, False, [only, the, spring, herald, to, spring])
# Random number, word in concern, is_stop_word: (3, to, True, [only, the, spring, herald, to, spring, to])
# Random number, word in concern, is_stop_word: (3, to, True, [only, the, spring, herald, to, spring, to, to])
# Random number, word in concern, is_stop_word: (5, gaudy, False, [only, the, spring, herald, to, spring, to, to, gaudy])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', groom)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('JJ', gaudy)
# Result sentence:('NN', flame)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'groom', 'to', 'the', 'turkish', 'flame'], 'JJ', 'turkish')
# POS:(['and', 'only', 'groom', 'to', 'the', 'scarlet', 'flame'], 'JJ', 'scarlet')
# POS:(['and', 'only', 'groom', 'to', 'the', 'exact', 'flame'], 'JJ', 'exact')
# POS:(['and', 'only', 'groom', 'to', 'the', 'imperious', 'flame'], 'JJ', 'imperious')
# POS:(['and', 'only', 'groom', 'to', 'the', 'careful', 'flame'], 'JJ', 'careful')
# POS:(['and', 'only', 'groom', 'to', 'the', 'villainous', 'flame'], 'JJ', 'villainous')
# POS:(['and', 'only', 'groom', 'to', 'the', 'howl', 'flame'], 'NN', 'howl')
# POS:(['and', 'only', 'groom', 'to', 'the', 'neat', 'flame'], 'JJ', 'neat')
# POS:(['and', 'only', 'groom', 'to', 'the', 'en', 'flame'], 'NN', 'en')
# POS:(['and', 'only', 'groom', 'to', 'the', 'jocund', 'flame'], 'JJ', 'jocund')
# POS:(['and', 'only', 'groom', 'to', 'the', 'suburbs', 'flame'], 'NNS', 'suburbs')
# POS:(['and', 'only', 'groom', 'to', 'the', 'superfluous', 'flame'], 'JJ', 'superfluous')
# POS:(['and', 'only', 'groom', 'to', 'the', 'ridiculous', 'flame'], 'JJ', 'ridiculous')
# POS:(['and', 'only', 'groom', 'to', 'the', 'spectacle', 'flame'], 'NN', 'spectacle')
# POS:(['and', 'only', 'groom', 'to', 'the', 'cargo', 'flame'], 'NN', 'cargo')
# POS:(['and', 'only', 'groom', 'to', 'the', 'moody', 'flame'], 'JJ', 'moody')
# POS:(['and', 'only', 'groom', 'to', 'the', 'diana’s', 'flame'], 'NNP', 'diana’s')
# POS:(['and', 'only', 'groom', 'to', 'the', 'applause', 'flame'], 'NN', 'applause')
# POS:(['and', 'only', 'groom', 'to', 'the', 'ungentle', 'flame'], 'JJ', 'ungentle')
# POS:(['and', 'only', 'groom', 'to', 'the', 'foison', 'flame'], 'NNP', 'foison')
# JJ gaudy
# List 2: ['turkish', 'scarlet', 'exact', 'imperious', 'careful', 'villainous', 'neat', 'jocund', 'superfluous', 'ridiculous', 'moody', 'ungentle']
#
# word in concern: neat
#
# then True
# being True
# asked False
# where True
# all True
# thy False
# beauty False
# lies False
# 5
# Debugging process: (where, True, [where], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', beauty)
# Result sentence:('NNS', lies)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'stands'], 'NNS', 'stands')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'comes'], 'VBZ', 'comes')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'goes'], 'VBZ', 'goes')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'is'], 'VBZ', 'is')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'grows'], 'VBZ', 'grows')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'seems'], 'VBZ', 'seems')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'dies'], 'VBZ', 'dies')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lodges'], 'NNS', 'lodges')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'appears'], 'VBZ', 'appears')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lo'], 'NNP', 'lo')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'bears'], 'NNS', 'bears')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'holds'], 'NNS', 'holds')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'who’s'], 'WP', 'who’s')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'begins'], 'VBZ', 'begins')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'sits'], 'VBZ', 'sits')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'resides'], 'VBZ', 'resides')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'started'], 'VBD', 'started')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'speaks'], 'VBZ', 'speaks')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'was'], 'VBD', 'was')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lives'], 'NNS', 'lives')
# NNS lies
# List 2: ['stands', 'lodges', 'bears', 'holds', 'lives']
#
# word in concern: stands
#
# Debugging process: (beauty, False, [where, being, lies, beauty], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', beauty)
# Result sentence:('NNS', stands)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'virtue', 'stands'], 'NN', 'virtue')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'age', 'stands'], 'NN', 'age')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'sorrow', 'stands'], 'NN', 'sorrow')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'breath', 'stands'], 'NN', 'breath')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'grief', 'stands'], 'NN', 'grief')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'nature', 'stands'], 'NN', 'nature')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'flesh', 'stands'], 'NN', 'flesh')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'eye', 'stands'], 'NN', 'eye')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'youth', 'stands'], 'NN', 'youth')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'valour', 'stands'], 'NN', 'valour')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'pride', 'stands'], 'NN', 'pride')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'face', 'stands'], 'NN', 'face')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'strength', 'stands'], 'NN', 'strength')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'blood', 'stands'], 'NN', 'blood')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'tongue', 'stands'], 'NN', 'tongue')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'death', 'stands'], 'NN', 'death')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'fortune', 'stands'], 'NN', 'fortune')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'sense', 'stands'], 'NN', 'sense')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'joy', 'stands'], 'NN', 'joy')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'book', 'stands'], 'NN', 'book')
# NN beauty
# List 2: ['virtue', 'age', 'sorrow', 'breath', 'grief', 'nature', 'flesh', 'eye', 'youth', 'valour', 'pride', 'face', 'strength', 'blood', 'tongue', 'death', 'fortune', 'sense', 'joy', 'book']
#
# word in concern: blood
#
# Debugging process: (then, True, [where, being, lies, beauty, then], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, beauty, then, lies])
# Random number, word in concern, is_stop_word: (4, all, True, [where, being, lies, beauty, then, lies, all])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being, lies, beauty, then, lies, all, where, being])
# Random number, word in concern, is_stop_word: (5, thy, False, [where, being, lies, beauty, then, lies, all, where, being, thy])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where])
# Random number, word in concern, is_stop_word: (5, thy, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies])
# Random number, word in concern, is_stop_word: (4, all, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty, being])
# Random number, word in concern, is_stop_word: (2, asked, False, [where, being, lies, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty, being, asked])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', blood)
# Result sentence:('VBZ', stands)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'warmth', 'where', 'all', 'thy', 'blood', 'stands'], 'NN', 'warmth')
# POS:(['then', 'being', 'unkind', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'unkind')
# POS:(['then', 'being', 'hush', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'hush')
# POS:(['then', 'being', 'disguise', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'disguise')
# POS:(['then', 'being', 'moral', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'moral')
# POS:(['then', 'being', 'capon', 'where', 'all', 'thy', 'blood', 'stands'], 'RB', 'capon')
# POS:(['then', 'being', 'rhyme', 'where', 'all', 'thy', 'blood', 'stands'], 'NNS', 'rhyme')
# POS:(['then', 'being', 'avoided', 'where', 'all', 'thy', 'blood', 'stands'], 'VBN', 'avoided')
# POS:(['then', 'being', 'quittance', 'where', 'all', 'thy', 'blood', 'stands'], 'NN', 'quittance')
# POS:(['then', 'being', 'likelihood', 'where', 'all', 'thy', 'blood', 'stands'], 'VBN', 'likelihood')
# POS:(['then', 'being', 'certainty', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'certainty')
# POS:(['then', 'being', 'latin', 'where', 'all', 'thy', 'blood', 'stands'], 'RB', 'latin')
# POS:(['then', 'being', 'troublesome', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'troublesome')
# POS:(['then', 'being', 'fulvia', 'where', 'all', 'thy', 'blood', 'stands'], 'NNP', 'fulvia')
# POS:(['then', 'being', 'apprehended', 'where', 'all', 'thy', 'blood', 'stands'], 'VBN', 'apprehended')
# POS:(['then', 'being', 'likely', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'likely')
# POS:(['then', 'being', 'validity', 'where', 'all', 'thy', 'blood', 'stands'], 'NN', 'validity')
# POS:(['then', 'being', 'knowing', 'where', 'all', 'thy', 'blood', 'stands'], 'VBG', 'knowing')
# POS:(['then', 'being', 'relish', 'where', 'all', 'thy', 'blood', 'stands'], 'JJ', 'relish')
# POS:(['then', 'being', 'bolt', 'where', 'all', 'thy', 'blood', 'stands'], 'NN', 'bolt')
# VBN asked
# List 2: ['avoided', 'likelihood', 'apprehended']
#
# word in concern: apprehended
#
# calls False
# back True
# the True
# lovely False
# april False
# of True
# her True
# prime False
# 4
# Debugging process: (april, False, [april], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', lovely)
# Result sentence:('NNP', april)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'lovely', 'meal', 'of', 'her', 'prime'], 'NN', 'meal')
# POS:(['calls', 'back', 'the', 'lovely', 'limits', 'of', 'her', 'prime'], 'NNS', 'limits')
# POS:(['calls', 'back', 'the', 'lovely', 'fashions', 'of', 'her', 'prime'], 'NNS', 'fashions')
# POS:(['calls', 'back', 'the', 'lovely', 'crest', 'of', 'her', 'prime'], 'NN', 'crest')
# POS:(['calls', 'back', 'the', 'lovely', 'echo', 'of', 'her', 'prime'], 'NN', 'echo')
# POS:(['calls', 'back', 'the', 'lovely', 'yawn', 'of', 'her', 'prime'], 'NN', 'yawn')
# POS:(['calls', 'back', 'the', 'lovely', 'mortality', 'of', 'her', 'prime'], 'NN', 'mortality')
# POS:(['calls', 'back', 'the', 'lovely', 'stately', 'of', 'her', 'prime'], 'NN', 'stately')
# POS:(['calls', 'back', 'the', 'lovely', 'bands', 'of', 'her', 'prime'], 'NNS', 'bands')
# POS:(['calls', 'back', 'the', 'lovely', 'towers', 'of', 'her', 'prime'], 'NNS', 'towers')
# POS:(['calls', 'back', 'the', 'lovely', 'philomel', 'of', 'her', 'prime'], 'NN', 'philomel')
# POS:(['calls', 'back', 'the', 'lovely', 'buds', 'of', 'her', 'prime'], 'NNS', 'buds')
# POS:(['calls', 'back', 'the', 'lovely', 'coffers', 'of', 'her', 'prime'], 'NNS', 'coffers')
# POS:(['calls', 'back', 'the', 'lovely', 'sap', 'of', 'her', 'prime'], 'NN', 'sap')
# POS:(['calls', 'back', 'the', 'lovely', 'growth', 'of', 'her', 'prime'], 'NN', 'growth')
# POS:(['calls', 'back', 'the', 'lovely', 'virgins', 'of', 'her', 'prime'], 'NNS', 'virgins')
# POS:(['calls', 'back', 'the', 'lovely', 'slumber', 'of', 'her', 'prime'], 'NN', 'slumber')
# POS:(['calls', 'back', 'the', 'lovely', 'clamour', 'of', 'her', 'prime'], 'NN', 'clamour')
# POS:(['calls', 'back', 'the', 'lovely', 'growing', 'of', 'her', 'prime'], 'NN', 'growing')
# POS:(['calls', 'back', 'the', 'lovely', 'pour’d', 'of', 'her', 'prime'], 'NN', 'pour’d')
# NNP april
# List 2: []
#
# Debugging process: (back, True, [april, back], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Random number, word in concern, is_stop_word: (5, of, True, [april, back, of])
# Random number, word in concern, is_stop_word: (6, her, True, [april, back, of, her])
# Random number, word in concern, is_stop_word: (3, lovely, False, [april, back, of, her, lovely])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', lovely)
# Result sentence:('NNP', april)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'dame', 'pour’d', 'of', 'her', 'prime'], 'JJ', 'dame')
# POS:(['calls', 'back', 'the', 'tribune', 'pour’d', 'of', 'her', 'prime'], 'JJ', 'tribune')
# POS:(['calls', 'back', 'the', 'nephew', 'pour’d', 'of', 'her', 'prime'], 'NN', 'nephew')
# POS:(['calls', 'back', 'the', 'unpleasing', 'pour’d', 'of', 'her', 'prime'], 'NN', 'unpleasing')
# POS:(['calls', 'back', 'the', 'rivers', 'pour’d', 'of', 'her', 'prime'], 'NNS', 'rivers')
# POS:(['calls', 'back', 'the', 'baby', 'pour’d', 'of', 'her', 'prime'], 'NN', 'baby')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'prime'], 'JJ', 'boisterous')
# POS:(['calls', 'back', 'the', 'worthless', 'pour’d', 'of', 'her', 'prime'], 'JJ', 'worthless')
# POS:(['calls', 'back', 'the', 'margery', 'pour’d', 'of', 'her', 'prime'], 'NN', 'margery')
# POS:(['calls', 'back', 'the', 'cardinal’s', 'pour’d', 'of', 'her', 'prime'], 'NN', 'cardinal’s')
# POS:(['calls', 'back', 'the', 'goddess', 'pour’d', 'of', 'her', 'prime'], 'NN', 'goddess')
# POS:(['calls', 'back', 'the', 'sulphurous', 'pour’d', 'of', 'her', 'prime'], 'JJ', 'sulphurous')
# POS:(['calls', 'back', 'the', 'plate', 'pour’d', 'of', 'her', 'prime'], 'NN', 'plate')
# POS:(['calls', 'back', 'the', 'climbing', 'pour’d', 'of', 'her', 'prime'], 'NN', 'climbing')
# POS:(['calls', 'back', 'the', 'spain', 'pour’d', 'of', 'her', 'prime'], 'NNP', 'spain')
# POS:(['calls', 'back', 'the', 'exile', 'pour’d', 'of', 'her', 'prime'], 'NN', 'exile')
# POS:(['calls', 'back', 'the', 'despis’d', 'pour’d', 'of', 'her', 'prime'], 'NN', 'despis’d')
# POS:(['calls', 'back', 'the', 'sues', 'pour’d', 'of', 'her', 'prime'], 'NNS', 'sues')
# POS:(['calls', 'back', 'the', 'usurping', 'pour’d', 'of', 'her', 'prime'], 'NN', 'usurping')
# POS:(['calls', 'back', 'the', 'andromache', 'pour’d', 'of', 'her', 'prime'], 'NNP', 'andromache')
# JJ lovely
# List 2: ['dame', 'tribune', 'boisterous', 'worthless', 'sulphurous']
#
# word in concern: boisterous
#
# Debugging process: (april, False, [april, back, of, her, lovely, april], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Random number, word in concern, is_stop_word: (7, prime, False, [april, back, of, her, lovely, april, prime])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', boisterous)
# Result sentence:('NN', pour’d)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'malady'], 'JJ', 'malady')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'plots'], 'NNS', 'plots')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'worthiest'], 'JJS', 'worthiest')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'slanders'], 'NNS', 'slanders')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'syria'], 'NNP', 'syria')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'infectious'], 'JJ', 'infectious')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'breathing'], 'NN', 'breathing')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'grand'], 'JJ', 'grand')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'reports'], 'NNS', 'reports')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'patch'], 'NN', 'patch')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'becoming'], 'VBG', 'becoming')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'household'], 'NN', 'household')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'lawless'], 'JJ', 'lawless')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'steps'], 'NNS', 'steps')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'rascals'], 'NNS', 'rascals')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'accent'], 'NN', 'accent')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'lord’s'], 'NNP', 'lord’s')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'sails'], 'NNS', 'sails')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'piercing'], 'VBG', 'piercing')
# POS:(['calls', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'JJ', 'latter')
# JJ prime
# List 2: ['malady', 'infectious', 'grand', 'lawless', 'latter']
#
# word in concern: latter
#
# Debugging process: (her, True, [april, back, of, her, lovely, april, prime, her], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Random number, word in concern, is_stop_word: (0, calls, False, [april, back, of, her, lovely, april, prime, her, calls])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', boisterous)
# Result sentence:('NN', pour’d)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', latter)
# Does this Word2Vec model have this word?  True
# POS:(['sends', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'sends')
# POS:(['writes', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'writes')
# POS:(['speaks', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'speaks')
# POS:(['swore', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBD', 'swore')
# POS:(['takes', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'takes')
# POS:(['hears', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'hears')
# POS:(['wore', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBD', 'wore')
# POS:(['tells', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'tells')
# POS:(['holds', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'holds')
# POS:(['greets', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'NNS', 'greets')
# POS:(['dies', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'dies')
# POS:(['slew', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'CC', 'slew')
# POS:(['utters', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'NNS', 'utters')
# POS:(['swears', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'swears')
# POS:(['hates', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'hates')
# POS:(['sees', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'sees')
# POS:(['likes', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'likes')
# POS:(['wears', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'wears')
# POS:(['bestows', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'bestows')
# POS:(['carries', 'back', 'the', 'boisterous', 'pour’d', 'of', 'her', 'latter'], 'VBZ', 'carries')
# VBZ calls
# List 2: ['sends', 'writes', 'speaks', 'takes', 'hears', 'tells', 'holds', 'dies', 'swears', 'hates', 'sees', 'likes', 'wears', 'bestows', 'carries']
#
# word in concern: dies
#
# then True
# beauteous False
# niggard False
# why True
# dost False
# thou False
# abuse False
# 4
# Debugging process: (beauteous, False, [beauteous], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Result sentence:('RB', then)
# Result sentence:('JJ', beauteous)
# Result sentence:('NN', niggard)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'empty', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'empty')
# POS:(['then', 'entrails', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VBZ', 'entrails')
# POS:(['then', 'fierce', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NNP', 'fierce')
# POS:(['then', 'youthful', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'youthful')
# POS:(['then', 'insurrection', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NN', 'insurrection')
# POS:(['then', 'cloth', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'cloth')
# POS:(['then', 'qualities', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NNS', 'qualities')
# POS:(['then', 'bastardy', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VBD', 'bastardy')
# POS:(['then', 'ken', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NNP', 'ken')
# POS:(['then', 'delicate', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'delicate')
# POS:(['then', 'alcides', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VBZ', 'alcides')
# POS:(['then', 'searching', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VBG', 'searching')
# POS:(['then', 'plate', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'plate')
# POS:(['then', 'nerves', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VBZ', 'nerves')
# POS:(['then', 'envious', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'envious')
# POS:(['then', 'stern', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NNP', 'stern')
# POS:(['then', 'lusty', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NNP', 'lusty')
# POS:(['then', 'courtier’s', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NN', 'courtier’s')
# POS:(['then', 'preferment', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NN', 'preferment')
# POS:(['then', 'hue', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'NN', 'hue')
# JJ beauteous
# List 2: ['empty', 'youthful', 'delicate', 'envious']
#
# word in concern: envious
#
# Debugging process: (why, True, [beauteous, why], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Random number, word in concern, is_stop_word: (5, thou, False, [beauteous, why, thou])
# Random number, word in concern, is_stop_word: (1, beauteous, False, [beauteous, why, thou, beauteous])
# Random number, word in concern, is_stop_word: (2, niggard, False, [beauteous, why, thou, beauteous, niggard])
# Result sentence:('RB', then)
# Result sentence:('JJ', envious)
# Result sentence:('NN', niggard)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'envious', 'vainly', 'why', 'dost', 'thou', 'abuse'], 'RB', 'vainly')
# POS:(['then', 'envious', 'baser', 'why', 'dost', 'thou', 'abuse'], 'NN', 'baser')
# POS:(['then', 'envious', 'rarest', 'why', 'dost', 'thou', 'abuse'], 'RB', 'rarest')
# POS:(['then', 'envious', 'palaces', 'why', 'dost', 'thou', 'abuse'], 'NNS', 'palaces')
# POS:(['then', 'envious', 'unequal', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'unequal')
# POS:(['then', 'envious', 'heavier', 'why', 'dost', 'thou', 'abuse'], 'JJR', 'heavier')
# POS:(['then', 'envious', 'muffled', 'why', 'dost', 'thou', 'abuse'], 'VBD', 'muffled')
# POS:(['then', 'envious', 'appearance', 'why', 'dost', 'thou', 'abuse'], 'NN', 'appearance')
# POS:(['then', 'envious', 'notwithstanding', 'why', 'dost', 'thou', 'abuse'], 'IN', 'notwithstanding')
# POS:(['then', 'envious', 'breathing', 'why', 'dost', 'thou', 'abuse'], 'NN', 'breathing')
# POS:(['then', 'envious', 'enrich', 'why', 'dost', 'thou', 'abuse'], 'NN', 'enrich')
# POS:(['then', 'envious', 'artificial', 'why', 'dost', 'thou', 'abuse'], 'NN', 'artificial')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'abuse'], 'NN', 'custom')
# POS:(['then', 'envious', 'embossed', 'why', 'dost', 'thou', 'abuse'], 'VBD', 'embossed')
# POS:(['then', 'envious', 'eloquence', 'why', 'dost', 'thou', 'abuse'], 'NN', 'eloquence')
# POS:(['then', 'envious', 'pernicious', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'pernicious')
# POS:(['then', 'envious', 'compos’d', 'why', 'dost', 'thou', 'abuse'], 'NNS', 'compos’d')
# POS:(['then', 'envious', 'patch', 'why', 'dost', 'thou', 'abuse'], 'NN', 'patch')
# POS:(['then', 'envious', 'active', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'active')
# POS:(['then', 'envious', 'determined', 'why', 'dost', 'thou', 'abuse'], 'VBD', 'determined')
# NN niggard
# List 2: ['baser', 'appearance', 'breathing', 'enrich', 'artificial', 'custom', 'eloquence', 'patch']
#
# word in concern: custom
#
# Debugging process: (then, True, [beauteous, why, thou, beauteous, niggard, then], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Random number, word in concern, is_stop_word: (3, why, True, [beauteous, why, thou, beauteous, niggard, then, why])
# Random number, word in concern, is_stop_word: (5, thou, False, [beauteous, why, thou, beauteous, niggard, then, why, thou])
# Random number, word in concern, is_stop_word: (4, dost, False, [beauteous, why, thou, beauteous, niggard, then, why, thou, dost])
# Random number, word in concern, is_stop_word: (0, then, True, [beauteous, why, thou, beauteous, niggard, then, why, thou, dost, then])
# Random number, word in concern, is_stop_word: (6, abuse, False, [beauteous, why, thou, beauteous, niggard, then, why, thou, dost, then, abuse])
# Result sentence:('RB', then)
# Result sentence:('JJ', envious)
# Result sentence:('NN', custom)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'hire'], 'NN', 'hire')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'language'], 'NN', 'language')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'unworthiness'], 'NN', 'unworthiness')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'hinder'], 'NN', 'hinder')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'manage'], 'NN', 'manage')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'bounty'], 'NN', 'bounty')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'assay'], 'NN', 'assay')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'discourse'], 'NN', 'discourse')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'curb'], 'NN', 'curb')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'relish'], 'NN', 'relish')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'lightness'], 'NN', 'lightness')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'fancy'], 'NN', 'fancy')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'bait'], 'NN', 'bait')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'welkin'], 'NN', 'welkin')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'cleave'], 'NN', 'cleave')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'object'], 'NN', 'object')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'afflict'], 'NN', 'afflict')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'ruin'], 'NNP', 'ruin')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'disgrace'], 'NN', 'disgrace')
# POS:(['then', 'envious', 'custom', 'why', 'dost', 'thou', 'paint'], 'NN', 'paint')
# NN abuse
# List 2: ['hire', 'language', 'unworthiness', 'hinder', 'manage', 'bounty', 'assay', 'discourse', 'curb', 'relish', 'lightness', 'fancy', 'bait', 'welkin', 'cleave', 'object', 'afflict', 'disgrace', 'paint']
#
# word in concern: bounty
#
# a True
# liquid False
# prisoner False
# pent False
# in True
# walls False
# of True
# glass False
# 3
# Debugging process: (of, True, [of], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', prisoner)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', walls)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'gates', 'of', 'glass'], 'NNS', 'gates')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'west', 'of', 'glass'], 'NN', 'west')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'temple', 'of', 'glass'], 'NN', 'temple')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'cave', 'of', 'glass'], 'NN', 'cave')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'battle', 'of', 'glass'], 'NN', 'battle')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'gate', 'of', 'glass'], 'NN', 'gate')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'view', 'of', 'glass'], 'NN', 'view')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'castle', 'of', 'glass'], 'NN', 'castle')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'streets', 'of', 'glass'], 'NNS', 'streets')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'top', 'of', 'glass'], 'NN', 'top')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'city', 'of', 'glass'], 'NN', 'city')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'army', 'of', 'glass'], 'NN', 'army')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'coast', 'of', 'glass'], 'NN', 'coast')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'laws', 'of', 'glass'], 'NNS', 'laws')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'glass'], 'NNS', 'forces')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'wood', 'of', 'glass'], 'NN', 'wood')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'realm', 'of', 'glass'], 'NN', 'realm')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'north', 'of', 'glass'], 'NN', 'north')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'town', 'of', 'glass'], 'NN', 'town')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'tower', 'of', 'glass'], 'NN', 'tower')
# NNS walls
# List 2: ['gates', 'streets', 'laws', 'forces']
#
# word in concern: forces
#
# Debugging process: (a, True, [of, walls, a], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (7, glass, False, [of, walls, a, glass])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', prisoner)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', forces)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'ambition'], 'NN', 'ambition')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'aspect')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'stroke'], 'NN', 'stroke')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'coat'], 'NN', 'coat')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'malice'], 'NN', 'malice')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'riot'], 'NN', 'riot')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'livery'], 'NN', 'livery')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'burden'], 'NN', 'burden')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'baseness'], 'NN', 'baseness')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'substance'], 'NN', 'substance')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'image'], 'NN', 'image')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'passage'], 'NN', 'passage')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'fee'], 'NN', 'fee')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'payment'], 'NN', 'payment')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'vanity'], 'NN', 'vanity')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'sharp'], 'JJ', 'sharp')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'cunning'], 'NN', 'cunning')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'broken'], 'JJ', 'broken')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'wild'], 'JJ', 'wild')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'forces', 'of', 'outward'], 'NN', 'outward')
# NN glass
# List 2: ['ambition', 'aspect', 'stroke', 'coat', 'malice', 'riot', 'livery', 'burden', 'baseness', 'substance', 'image', 'passage', 'fee', 'payment', 'vanity', 'cunning', 'outward']
#
# word in concern: aspect
#
# Debugging process: (in, True, [of, walls, a, glass, in], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [of, walls, a, glass, in, of, prisoner])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', prisoner)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', forces)
# Result sentence:('IN', of)
# Result sentence:('NN', aspect)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'liquid', 'rudeness', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'rudeness')
# POS:(['a', 'liquid', 'dagger', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'dagger')
# POS:(['a', 'liquid', 'cue', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'cue')
# POS:(['a', 'liquid', 'revenue', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'revenue')
# POS:(['a', 'liquid', 'behaviour', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'behaviour')
# POS:(['a', 'liquid', 'capacity', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'capacity')
# POS:(['a', 'liquid', 'pawned', 'pent', 'in', 'forces', 'of', 'aspect'], 'VBN', 'pawned')
# POS:(['a', 'liquid', 'schoolmaster', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'schoolmaster')
# POS:(['a', 'liquid', 'banish’d', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'banish’d')
# POS:(['a', 'liquid', 'confessor', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'confessor')
# POS:(['a', 'liquid', 'steed', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'steed')
# POS:(['a', 'liquid', 'creditor', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'creditor')
# POS:(['a', 'liquid', 'reputation', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'reputation')
# POS:(['a', 'liquid', 'grandfather', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'grandfather')
# POS:(['a', 'liquid', 'blessing', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'blessing')
# POS:(['a', 'liquid', 'dukedom', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'dukedom')
# POS:(['a', 'liquid', 'breeding', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'breeding')
# POS:(['a', 'liquid', 'instrument', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'instrument')
# POS:(['a', 'liquid', 'banished', 'pent', 'in', 'forces', 'of', 'aspect'], 'VBN', 'banished')
# POS:(['a', 'liquid', 'hat', 'pent', 'in', 'forces', 'of', 'aspect'], 'NN', 'hat')
# NN prisoner
# List 2: ['rudeness', 'dagger', 'cue', 'revenue', 'behaviour', 'capacity', 'schoolmaster', 'banish’d', 'confessor', 'steed', 'creditor', 'reputation', 'grandfather', 'blessing', 'dukedom', 'breeding', 'instrument', 'hat']
#
# word in concern: capacity
#
# Debugging process: (pent, False, [of, walls, a, glass, in, of, prisoner, pent], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', capacity)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', forces)
# Result sentence:('IN', of)
# Result sentence:('NN', aspect)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'liquid', 'capacity', 'moist', 'in', 'forces', 'of', 'aspect'], 'NN', 'moist')
# POS:(['a', 'liquid', 'capacity', 'corruption', 'in', 'forces', 'of', 'aspect'], 'NN', 'corruption')
# POS:(['a', 'liquid', 'capacity', 'rust', 'in', 'forces', 'of', 'aspect'], 'NN', 'rust')
# POS:(['a', 'liquid', 'capacity', 'whatever', 'in', 'forces', 'of', 'aspect'], 'WDT', 'whatever')
# POS:(['a', 'liquid', 'capacity', 'buds', 'in', 'forces', 'of', 'aspect'], 'NNS', 'buds')
# POS:(['a', 'liquid', 'capacity', 'despairing', 'in', 'forces', 'of', 'aspect'], 'VBG', 'despairing')
# POS:(['a', 'liquid', 'capacity', 'triumphant', 'in', 'forces', 'of', 'aspect'], 'JJ', 'triumphant')
# POS:(['a', 'liquid', 'capacity', 'feeble', 'in', 'forces', 'of', 'aspect'], 'JJ', 'feeble')
# POS:(['a', 'liquid', 'capacity', 'roof', 'in', 'forces', 'of', 'aspect'], 'NN', 'roof')
# POS:(['a', 'liquid', 'capacity', 'restless', 'in', 'forces', 'of', 'aspect'], 'JJ', 'restless')
# POS:(['a', 'liquid', 'capacity', 'stately', 'in', 'forces', 'of', 'aspect'], 'JJ', 'stately')
# POS:(['a', 'liquid', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'VBN', 'strucken')
# POS:(['a', 'liquid', 'capacity', 'snow-white', 'in', 'forces', 'of', 'aspect'], 'NN', 'snow-white')
# POS:(['a', 'liquid', 'capacity', 'trimm’d', 'in', 'forces', 'of', 'aspect'], 'NN', 'trimm’d')
# POS:(['a', 'liquid', 'capacity', 'wormwood', 'in', 'forces', 'of', 'aspect'], 'NN', 'wormwood')
# POS:(['a', 'liquid', 'capacity', 'torn', 'in', 'forces', 'of', 'aspect'], 'VBN', 'torn')
# POS:(['a', 'liquid', 'capacity', 'majestical', 'in', 'forces', 'of', 'aspect'], 'JJ', 'majestical')
# POS:(['a', 'liquid', 'capacity', 'winged', 'in', 'forces', 'of', 'aspect'], 'VBN', 'winged')
# POS:(['a', 'liquid', 'capacity', 'spiritual', 'in', 'forces', 'of', 'aspect'], 'JJ', 'spiritual')
# POS:(['a', 'liquid', 'capacity', 'gilded', 'in', 'forces', 'of', 'aspect'], 'VBN', 'gilded')
# VBN pent
# List 2: ['strucken', 'torn', 'winged', 'gilded']
#
# word in concern: strucken
#
# Debugging process: (pent, False, [of, walls, a, glass, in, of, prisoner, pent, pent], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (3, pent, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls])
# Random number, word in concern, is_stop_word: (7, glass, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass])
# Random number, word in concern, is_stop_word: (4, in, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in])
# Random number, word in concern, is_stop_word: (0, a, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner])
# Random number, word in concern, is_stop_word: (3, pent, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of])
# Random number, word in concern, is_stop_word: (0, a, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a])
# Random number, word in concern, is_stop_word: (7, glass, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls])
# Random number, word in concern, is_stop_word: (3, pent, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of])
# Random number, word in concern, is_stop_word: (7, glass, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls])
# Random number, word in concern, is_stop_word: (6, of, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls])
# Random number, word in concern, is_stop_word: (0, a, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a])
# Random number, word in concern, is_stop_word: (5, walls, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls])
# Random number, word in concern, is_stop_word: (7, glass, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass])
# Random number, word in concern, is_stop_word: (0, a, True, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass, a])
# Random number, word in concern, is_stop_word: (3, pent, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass, a, pent])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass, a, pent, prisoner])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass, a, pent, prisoner, prisoner])
# Random number, word in concern, is_stop_word: (1, liquid, False, [of, walls, a, glass, in, of, prisoner, pent, pent, pent, of, walls, walls, glass, in, a, of, prisoner, pent, of, a, glass, walls, pent, of, glass, walls, of, walls, a, walls, glass, a, pent, prisoner, prisoner, liquid])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', capacity)
# Result sentence:('VBN', strucken)
# Result sentence:('IN', in)
# Result sentence:('NNS', forces)
# Result sentence:('IN', of)
# Result sentence:('NN', aspect)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'obscure', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'obscure')
# POS:(['a', 'eyeless', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'eyeless')
# POS:(['a', 'solace', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'solace')
# POS:(['a', 'sleeves', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NNS', 'sleeves')
# POS:(['a', "heaven's", 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NNP', "heaven's")
# POS:(['a', 'lamenting', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'VBG', 'lamenting')
# POS:(['a', 'jove’s', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'jove’s')
# POS:(['a', 'for’s', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'IN', 'for’s')
# POS:(['a', 'vast', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'vast')
# POS:(['a', 'basin', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'basin')
# POS:(['a', 'convert', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'convert')
# POS:(['a', 'eager', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'eager')
# POS:(['a', 'graceful', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'graceful')
# POS:(['a', 'mounting', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'VBG', 'mounting')
# POS:(['a', 'support', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'support')
# POS:(['a', 'rusty', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'rusty')
# POS:(['a', 'melting', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'melting')
# POS:(['a', 'frozen', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'JJ', 'frozen')
# POS:(['a', 'ivory', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'ivory')
# POS:(['a', 'boar’s', 'capacity', 'strucken', 'in', 'forces', 'of', 'aspect'], 'NN', 'boar’s')
# JJ liquid
# List 2: ['obscure', 'eyeless', 'vast', 'eager', 'graceful', 'rusty', 'frozen']
#
# word in concern: frozen
#
# that True
# use False
# is True
# not True
# forbidden False
# usury False
# 3
# Debugging process: (forbidden, False, [forbidden], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Result sentence:('DT', that)
# Result sentence:('NN', use)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', forbidden)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  True
# POS:(['that', 'use', 'is', 'not', 'stomachs', 'usury'], 'NNS', 'stomachs')
# POS:(['that', 'use', 'is', 'not', 'safe', 'usury'], 'JJ', 'safe')
# POS:(['that', 'use', 'is', 'not', 'amain', 'usury'], 'RB', 'amain')
# POS:(['that', 'use', 'is', 'not', 'starve', 'usury'], 'VB', 'starve')
# POS:(['that', 'use', 'is', 'not', 'apart', 'usury'], 'RB', 'apart')
# POS:(['that', 'use', 'is', 'not', 'excused', 'usury'], 'VBN', 'excused')
# POS:(['that', 'use', 'is', 'not', 'restored', 'usury'], 'VBN', 'restored')
# POS:(['that', 'use', 'is', 'not', 'driven', 'usury'], 'VBN', 'driven')
# POS:(['that', 'use', 'is', 'not', 'compell’d', 'usury'], 'VB', 'compell’d')
# POS:(['that', 'use', 'is', 'not', 'twain', 'usury'], 'RB', 'twain')
# POS:(['that', 'use', 'is', 'not', 'admitted', 'usury'], 'VBN', 'admitted')
# POS:(['that', 'use', 'is', 'not', 'directed', 'usury'], 'VBN', 'directed')
# POS:(['that', 'use', 'is', 'not', 'necessaries', 'usury'], 'NNS', 'necessaries')
# POS:(['that', 'use', 'is', 'not', 'duly', 'usury'], 'RB', 'duly')
# POS:(['that', 'use', 'is', 'not', 'combatants', 'usury'], 'NNS', 'combatants')
# POS:(['that', 'use', 'is', 'not', 'asunder', 'usury'], 'RB', 'asunder')
# POS:(['that', 'use', 'is', 'not', 'fig', 'usury'], 'NN', 'fig')
# POS:(['that', 'use', 'is', 'not', 'festival', 'usury'], 'NN', 'festival')
# POS:(['that', 'use', 'is', 'not', "to't", 'usury'], 'NN', "to't")
# POS:(['that', 'use', 'is', 'not', 'pine', 'usury'], 'JJ', 'pine')
# VBN forbidden
# List 2: ['excused', 'restored', 'driven', 'admitted', 'directed']
#
# word in concern: driven
#
# Debugging process: (that, True, [forbidden, that], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Random number, word in concern, is_stop_word: (5, usury, False, [forbidden, that, usury])
# Result sentence:('DT', that)
# Result sentence:('NN', use)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', driven)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  False
# Debugging process: (that, True, [forbidden, that, usury, that], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Random number, word in concern, is_stop_word: (0, that, True, [forbidden, that, usury, that, that])
# Random number, word in concern, is_stop_word: (0, that, True, [forbidden, that, usury, that, that, that])
# Random number, word in concern, is_stop_word: (3, not, True, [forbidden, that, usury, that, that, that, not])
# Random number, word in concern, is_stop_word: (0, that, True, [forbidden, that, usury, that, that, that, not, that])
# Random number, word in concern, is_stop_word: (2, is, True, [forbidden, that, usury, that, that, that, not, that, is])
# Random number, word in concern, is_stop_word: (1, use, False, [forbidden, that, usury, that, that, that, not, that, is, use])
# Result sentence:('DT', that)
# Result sentence:('NN', use)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', driven)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  True
# POS:(['that', 'praise', 'is', 'not', 'driven', 'usury'], 'NN', 'praise')
# POS:(['that', 'pay', 'is', 'not', 'driven', 'usury'], 'NN', 'pay')
# POS:(['that', 'pity', 'is', 'not', 'driven', 'usury'], 'NN', 'pity')
# POS:(['that', 'hate', 'is', 'not', 'driven', 'usury'], 'NN', 'hate')
# POS:(['that', 'wrong', 'is', 'not', 'driven', 'usury'], 'NN', 'wrong')
# POS:(['that', 'show', 'is', 'not', 'driven', 'usury'], 'NN', 'show')
# POS:(['that', 'lose', 'is', 'not', 'driven', 'usury'], 'NN', 'lose')
# POS:(['that', 'shame', 'is', 'not', 'driven', 'usury'], 'NN', 'shame')
# POS:(['that', 'hold', 'is', 'not', 'driven', 'usury'], 'NN', 'hold')
# POS:(['that', 'answer', 'is', 'not', 'driven', 'usury'], 'NN', 'answer')
# POS:(['that', 'eat', 'is', 'not', 'driven', 'usury'], 'NN', 'eat')
# POS:(['that', 'bear', 'is', 'not', 'driven', 'usury'], 'NN', 'bear')
# POS:(['that', 'talk', 'is', 'not', 'driven', 'usury'], 'NN', 'talk')
# POS:(['that', 'blame', 'is', 'not', 'driven', 'usury'], 'NN', 'blame')
# POS:(['that', 'weep', 'is', 'not', 'driven', 'usury'], 'NN', 'weep')
# POS:(['that', 'keep', 'is', 'not', 'driven', 'usury'], 'VBP', 'keep')
# POS:(['that', 'change', 'is', 'not', 'driven', 'usury'], 'NN', 'change')
# POS:(['that', 'fit', 'is', 'not', 'driven', 'usury'], 'NN', 'fit')
# POS:(['that', 'trust', 'is', 'not', 'driven', 'usury'], 'NN', 'trust')
# POS:(['that', 'desire', 'is', 'not', 'driven', 'usury'], 'NN', 'desire')
# NN use
# List 2: ['praise', 'pay', 'pity', 'hate', 'wrong', 'show', 'lose', 'shame', 'hold', 'answer', 'eat', 'bear', 'talk', 'blame', 'weep', 'change', 'fit', 'trust', 'desire']
#
# word in concern: hold
#
#
#
# Results
# and only groom to the neat flame
# then being apprehended where all thy blood stands
# dies back the boisterous pour’d of her latter
# then envious custom why dost thou bounty
# a frozen capacity strucken in forces of aspect
# that hold is not driven usury

# %%
##sentenceChecker.parse("The brown fox meal some chicken.")
nlp = spacy.load("en_core_web_sm")
results = nlp("The brown fox chicken some chicken.")
##for word in results:
  ##print(word,word.pos_,word.dep_,word.tag_)

##### Creating a word substitution method ########
##### Refer to the previous method.
def word_swap(wordList,sentenceInConcern,trueIndex):
  rand_index = random.randint(0,len(wordList)-1)
  rand_word = wordList[rand_index]
  print(f'word in concern: {rand_word}\n')
  sentenceInConcern.pop(trueIndex)
  sentenceInConcern.insert(trueIndex,rand_word)


###### Using the spacy method ########
random.seed(1)

##### Refer to the previous method.
def insert_delete(wordArray,indexInConcern,word):
  ##print(f"Initial: {wordArray}")
  wordArray.pop(indexInConcern)
  ##print(f"With word removed: {wordArray}")
  wordArray.insert(indexInConcern,word)
  ##print(f"With new word inserted: {wordArray}")
  current_Pos = nlp(" ".join(wordArray))[indexInConcern].tag_   ##+1].tag_
  return current_Pos

####Using the modern corpus model#######
sentencesList = list()

for index in range(1,100,10):
  testSentence = nGramCorpus[index]
  if (len(testSentence)!=3):
    sentence2 = testSentence[1:-1].copy()
    sentString = " ".join(sentence2)
    doc = nlp(sentString)
    docList = [str(w) for w in doc]
    stopWordCount = 0
    for token in doc:
      print(token,token.is_stop)
      if(token.is_stop or stop_words.count(str(token))!=0):
        stopWordCount+=1
    nonStopWordsCount = len(doc) - stopWordCount
    print(stopWordCount)
    wordsUsed = []
    for i in range(nonStopWordsCount):
      randInt = random.randint(0,len(doc)-1) ##1,len(testSentence)-2)
      wordInConcern = doc[randInt]        ##'sun'   ##testSentence[randInt]
      isStopWord = wordInConcern.is_stop  ####nlp(wordInConcern)[0].is_stop
      wordsUsed.append(wordInConcern)
      print(f"Debugging process: {wordInConcern,isStopWord,wordsUsed,sentence2}")
      if(isStopWord==True or wordsUsed.count(wordInConcern)>=2 or stop_words.count(str(wordInConcern))!=0):
        while(isStopWord==True or wordsUsed.count(wordInConcern)>=2 or stop_words.count(str(wordInConcern))!=0):
          randInt = random.randint(0,len(doc)-1)  ##1,len(testSentence)-2)
          wordInConcern = doc[randInt] ##testSentence[randInt]
          isStopWord = wordInConcern.is_stop  ##nlp(wordInConcern)[0].is_stop
          wordsUsed.append(wordInConcern)
          print(f"Random number, word in concern, is_stop_word: {randInt,wordInConcern,isStopWord,wordsUsed}")
      posInConcern = nlp(sentString)[randInt].tag_  ##randInt-1].tag_
      for i in range(len(nlp(sentString))):
        print(f"Result sentence:{nlp(sentString)[i].tag_,nlp(sentString)[i]}")
      print(f"Does this Word2Vec model have this word?  {anotherModel.key_to_index.get(str(wordInConcern))!=None}")
      if(anotherModel.key_to_index.get(str(wordInConcern))!=None):
        listOfPossibleWAndSim = anotherModel.most_similar([str(wordInConcern)],topn=20)
        testList = list()
        for w,s in listOfPossibleWAndSim:
          currentPOS= nlp(w)[0].tag_
          print(f"POS:{docList,posInConcern,currentPOS,w}")
          if (currentPOS == posInConcern):
            testList.append(w)
        print(posInConcern,wordInConcern)
        print(f"List 2: {testList}\n")
        if(len(testList)!=0):
          word_swap(testList,docList,randInt)   ##randInt-1)
          sentString = " ".join(docList)
    sentencesList.append(sentString)

print("\n\nResults")
for sentence in sentencesList:
  print(sentence)
sentencesList.clear()
# Out:
# and True
# only True
# herald False
# to True
# the True
# gaudy False
# spring False
# 4
# Debugging process: (only, True, [only], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Random number, word in concern, is_stop_word: (4, the, True, [only, the])
# Random number, word in concern, is_stop_word: (6, spring, False, [only, the, spring])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', herald)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('JJ', gaudy)
# Result sentence:('NN', spring)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'summer')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'autumn')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'winter')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VBG', 'beginning')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VB', 'fall')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VB', 'start')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VBG', 'starting')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'year')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'RB', 'next')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NNS', 'days')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VBG', 'coming')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'day')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'IN', 'during')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'RB', 'early')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NNS', 'weeks')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'IN', 'until')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NNP', 'july')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'VB', 'begin')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'MD', 'may')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'], 'NN', 'NN', 'weekend')
# NN spring
# List 2: ['summer', 'autumn', 'winter', 'year', 'day', 'weekend']
#
# word in concern: summer
#
# Debugging process: (herald, False, [only, the, spring, herald], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', herald)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('NN', gaudy)
# Result sentence:('NN', summer)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'JJ', 'tribune')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'newspaper')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'chronicle')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'columnist')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'editorial')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'VB', 'gazette')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'RB', 'daily')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'newsday')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'inquirer')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'editor')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NNS', 'newspapers')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'news')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'enquirer')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NN', 'intelligencer')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'DT', 'com.the')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NNP', 'sentinel')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NNP', 'journal')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NNP', 'sarasota')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'VB', 'tabloid')
# POS:(['and', 'only', 'herald', 'to', 'the', 'gaudy', 'summer'], 'VB', 'NNP', 'cox')
# VB herald
# List 2: ['gazette', 'tabloid']
#
# word in concern: gazette
#
# Debugging process: (to, True, [only, the, spring, herald, to], ['and', 'only', 'herald', 'to', 'the', 'gaudy', 'spring'])
# Random number, word in concern, is_stop_word: (6, spring, False, [only, the, spring, herald, to, spring])
# Random number, word in concern, is_stop_word: (3, to, True, [only, the, spring, herald, to, spring, to])
# Random number, word in concern, is_stop_word: (3, to, True, [only, the, spring, herald, to, spring, to, to])
# Random number, word in concern, is_stop_word: (5, gaudy, False, [only, the, spring, herald, to, spring, to, to, gaudy])
# Result sentence:('CC', and)
# Result sentence:('RB', only)
# Result sentence:('VB', gazette)
# Result sentence:('IN', to)
# Result sentence:('DT', the)
# Result sentence:('NN', gaudy)
# Result sentence:('NN', summer)
# Does this Word2Vec model have this word?  True
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'garish')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'flashy')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NN', 'glittery')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'ostentatious')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'VBG', 'glittering')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'tacky')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'kitschy')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'shabby')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NN', 'opulent')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'snazzy')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'showy')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'glitzy')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'VBG', 'dazzling')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'outlandish')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NN', 'cartoonish')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'VBN', 'oversized')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'extravagant')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'NNP', 'cartoony')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'VBD', 'multicolored')
# POS:(['and', 'only', 'gazette', 'to', 'the', 'gaudy', 'summer'], 'NN', 'JJ', 'colorful')
# NN gaudy
# List 2: ['glittery', 'opulent', 'cartoonish']
#
# word in concern: opulent
#
# then True
# being True
# asked False
# where True
# all True
# thy False
# beauty False
# lies False
# 5
# Debugging process: (where, True, [where], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', beauty)
# Result sentence:('NNS', lies)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VB', 'lie')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBD', 'situated')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBN', 'located')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBG', 'lying')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NNP', 'north-east')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NNP', 'south-east')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NNP', 'south-west')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBZ', 'is')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NNP', 'east')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NN', 'north-west')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBZ', 'stretches')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NN', 'north')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'IN', 'beyond')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBD', 'bordered')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NN', 'area')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBZ', 'stands')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'VBZ', 'sits')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'IN', 'beneath')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'NNP', 'west')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NNS', 'IN', 'near')
# NNS lies
# List 2: []
#
# Debugging process: (then, True, [where, being, lies, then], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, then, beauty])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', beauty)
# Result sentence:('NNS', lies)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'beautiful')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'fashion')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'glamour')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'nature')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'love')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'life')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'natural')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'elegance')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'charm')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'wonderful')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'reality')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'artistic')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NNS', 'beauties')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'passion')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'incredible')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'amazing')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'obsession')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NN', 'essence')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'NNP', 'spirit')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'], 'NN', 'JJ', 'gorgeous')
# NN beauty
# List 2: ['fashion', 'glamour', 'nature', 'love', 'life', 'elegance', 'charm', 'reality', 'passion', 'obsession', 'essence']
#
# word in concern: charm
#
# Debugging process: (then, True, [where, being, lies, then, beauty, then], ['then', 'being', 'asked', 'where', 'all', 'thy', 'beauty', 'lies'])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, then, beauty, then, lies])
# Random number, word in concern, is_stop_word: (4, all, True, [where, being, lies, then, beauty, then, lies, all])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being, lies, then, beauty, then, lies, all, where, being])
# Random number, word in concern, is_stop_word: (5, thy, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where])
# Random number, word in concern, is_stop_word: (5, thy, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where])
# Random number, word in concern, is_stop_word: (3, where, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where])
# Random number, word in concern, is_stop_word: (7, lies, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies])
# Random number, word in concern, is_stop_word: (4, all, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all])
# Random number, word in concern, is_stop_word: (0, then, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then])
# Random number, word in concern, is_stop_word: (6, beauty, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty])
# Random number, word in concern, is_stop_word: (1, being, True, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty, being])
# Random number, word in concern, is_stop_word: (2, asked, False, [where, being, lies, then, beauty, then, lies, all, where, being, thy, then, then, then, then, beauty, where, beauty, then, where, lies, lies, where, thy, where, where, lies, all, then, beauty, being, asked])
# Result sentence:('RB', then)
# Result sentence:('VBG', being)
# Result sentence:('VBN', asked)
# Result sentence:('WRB', where)
# Result sentence:('DT', all)
# Result sentence:('PRP$', thy)
# Result sentence:('NN', charm)
# Result sentence:('NNS', lies)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'told')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VB', 'ask')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBG', 'asking')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'wanted')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBG', 'saying')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'did')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'IN', 'whether')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'decided')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'WRB', 'why')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'refused')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'said')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBG', 'telling')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'NN', 'interview')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VB', 'tell')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'explained')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'NNS', 'reporters')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'PRP', 'he')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBD', 'suggested')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VB', 'say')
# POS:(['then', 'being', 'asked', 'where', 'all', 'thy', 'charm', 'lies'], 'VBN', 'VBN', 'informed')
# VBN asked
# List 2: ['informed']
#
# word in concern: informed
#
# calls False
# back True
# the True
# lovely False
# april False
# of True
# her True
# prime False
# 4
# Debugging process: (back, True, [back], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Random number, word in concern, is_stop_word: (5, of, True, [back, of])
# Random number, word in concern, is_stop_word: (6, her, True, [back, of, her])
# Random number, word in concern, is_stop_word: (3, lovely, False, [back, of, her, lovely])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', lovely)
# Result sentence:('NNP', april)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'beautiful')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'gorgeous')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'wonderful')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'NNP', 'charming')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'delightful')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'elegant')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'fabulous')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'RB', 'wonderfully')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'nice')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'VB', 'cute')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'RB', 'beautifully')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'VB', 'magnificent')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'marvelous')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'VBD', 'splendid')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'VBG', 'enchanting')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'dreamy')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'handsome')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'delicious')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'RB', 'pretty')
# POS:(['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'], 'JJ', 'JJ', 'graceful')
# JJ lovely
# List 2: ['beautiful', 'gorgeous', 'wonderful', 'delightful', 'elegant', 'fabulous', 'nice', 'marvelous', 'dreamy', 'handsome', 'delicious', 'graceful']
#
# word in concern: elegant
#
# Debugging process: (april, False, [back, of, her, lovely, april], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', elegant)
# Result sentence:('NNP', april)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'june')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'july')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'october')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'february')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'september')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'november')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'december')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'august')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'march')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'january')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '26')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '29')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'dec.')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '28')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'NNP', 'aug.')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '21')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '27')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '31')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '23')
# POS:(['calls', 'back', 'the', 'elegant', 'april', 'of', 'her', 'prime'], 'NNP', 'CD', '19')
# NNP april
# List 2: ['june', 'july', 'october', 'february', 'september', 'november', 'december', 'august', 'march', 'january', 'dec.', 'aug.']
#
# word in concern: january
#
# Debugging process: (prime, False, [back, of, her, lovely, april, prime], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', elegant)
# Result sentence:('NN', january)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', prime)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'minister')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'cabinet')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'premier')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNS', 'ministers')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'leader')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'government')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNP', 'sharon')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNP', 'olmert')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'netanyahu')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNP', 'ehud')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'president')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNS', 'peres')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'JJ', 'foreign')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNP', 'blair')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'counterpart')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'opposition')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NNP', 'barak')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'party')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'NN', 'parliament')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'prime'], 'JJ', 'VBD', 'met')
# JJ prime
# List 2: ['foreign']
#
# word in concern: foreign
#
# Debugging process: (calls, False, [back, of, her, lovely, april, prime, calls], ['calls', 'back', 'the', 'lovely', 'april', 'of', 'her', 'prime'])
# Result sentence:('VBZ', calls)
# Result sentence:('RB', back)
# Result sentence:('DT', the)
# Result sentence:('JJ', elegant)
# Result sentence:('NN', january)
# Result sentence:('IN', of)
# Result sentence:('PRP$', her)
# Result sentence:('JJ', foreign)
# Does this Word2Vec model have this word?  True
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'calling')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VB', 'call')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'NN', 'response')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'asking')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBN', 'called')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'NNS', 'demands')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'referring')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VB', 'stop')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'urging')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'NN', 'message')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'saying')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VB', 'send')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VB', 'talk')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'NN', 'criticism')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBD', 'asked')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBZ', 'wants')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'seeking')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBG', 'warning')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'VBZ', 'says')
# POS:(['calls', 'back', 'the', 'elegant', 'january', 'of', 'her', 'foreign'], 'VBZ', 'JJS', 'latest')
# VBZ calls
# List 2: ['wants', 'says']
#
# word in concern: says
#
# then True
# beauteous False
# niggard False
# why True
# dost False
# thou False
# abuse False
# 4
# Debugging process: (beauteous, False, [beauteous], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Result sentence:('RB', then)
# Result sentence:('JJ', beauteous)
# Result sentence:('NN', niggard)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'street-wise')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'JJ', 'cretinous')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'JJ', 'glamourous')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'JJ', 'sweet-natured')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'JJ', 'free-spirited')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'RB', 'high-spirited')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'RB', 'tough-talking')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'complaisant')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'RB', 'well-bred')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'RB', 'slow-witted')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'peace-loving')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NNP', 'god-fearing')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'JJ', 'libidinous')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'class-conscious')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'self-important')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'VB', 'saturnine')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'self-obsessed')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'VBN', 'stuck-up')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'frolicsome')
# POS:(['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'JJ', 'NN', 'talentless')
# JJ beauteous
# List 2: ['cretinous', 'glamourous', 'sweet-natured', 'free-spirited', 'libidinous']
#
# word in concern: free-spirited
#
# Debugging process: (why, True, [beauteous, why], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Random number, word in concern, is_stop_word: (5, thou, False, [beauteous, why, thou])
# Random number, word in concern, is_stop_word: (1, beauteous, False, [beauteous, why, thou, beauteous])
# Random number, word in concern, is_stop_word: (2, niggard, False, [beauteous, why, thou, beauteous, niggard])
# Result sentence:('RB', then)
# Result sentence:('JJ', free)
# Result sentence:('HYPH', -)
# Result sentence:('JJ', spirited)
# Result sentence:('NN', niggard)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  False
# Debugging process: (dost, False, [beauteous, why, thou, beauteous, niggard, dost], ['then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse'])
# Random number, word in concern, is_stop_word: (5, thou, False, [beauteous, why, thou, beauteous, niggard, dost, thou])
# Random number, word in concern, is_stop_word: (6, abuse, False, [beauteous, why, thou, beauteous, niggard, dost, thou, abuse])
# Result sentence:('RB', then)
# Result sentence:('JJ', free)
# Result sentence:('HYPH', -)
# Result sentence:('JJ', spirited)
# Result sentence:('NN', niggard)
# Result sentence:('WRB', why)
# Result sentence:('VB', dost)
# Result sentence:('JJ', thou)
# Result sentence:('NN', abuse)
# Does this Word2Vec model have this word?  True
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'JJ', 'sexual')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'sex')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'abuses')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'allegations')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'rape')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'harassment')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'misconduct')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'torture')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'corruption')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'child')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'mistreatment')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'VBN', 'abused')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'cases')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'VB', 'neglect')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'accusations')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'complaints')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'priests')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'VBD', 'alleged')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NN', 'scandal')
# POS:(['then', 'free-spirited', 'niggard', 'why', 'dost', 'thou', 'abuse'], 'VB', 'NNS', 'charges')
# VB abuse
# List 2: ['neglect']
#
# word in concern: neglect
#
# a True
# liquid False
# prisoner False
# pent False
# in True
# walls False
# of True
# glass False
# 3
# Debugging process: (liquid, False, [liquid], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Result sentence:('DT', a)
# Result sentence:('JJ', liquid)
# Result sentence:('NN', prisoner)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', walls)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NNS', 'liquids')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'mixture')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'vapor')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'VBN', 'molten')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'hydrogen')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'JJ', 'flammable')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'JJ', 'fluid')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'helium')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'heat')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'surface')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'VB', 'propellant')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'VBG', 'boiling')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NNS', 'mixtures')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'oxygen')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'water')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'ammonia')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'VBD', 'cooled')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'VB', 'crystalline')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'NN', 'vacuum')
# POS:(['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'JJ', 'JJ', 'toxic')
# JJ liquid
# List 2: ['flammable', 'fluid', 'toxic']
#
# word in concern: fluid
#
# Debugging process: (liquid, False, [liquid, liquid], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [liquid, liquid, prisoner])
# Result sentence:('DT', a)
# Result sentence:('JJ', fluid)
# Result sentence:('NN', prisoner)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', walls)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'prisoners')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'detainee')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'detainees')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'VBN', 'freed')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'VBN', 'imprisoned')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'prison')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'custody')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNP', 'guantanamo')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'pows')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'hostage')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'soldier')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'captives')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'detention')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'JJ', 'captive')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'inmate')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'inmates')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'VBN', 'tortured')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'VBN', 'jailed')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NNS', 'hostages')
# POS:(['a', 'fluid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'], 'NN', 'NN', 'war')
# NN prisoner
# List 2: ['detainee', 'prison', 'custody', 'hostage', 'soldier', 'detention', 'inmate', 'war']
#
# word in concern: inmate
#
# Debugging process: (walls, False, [liquid, liquid, prisoner, walls], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Result sentence:('DT', a)
# Result sentence:('JJ', fluid)
# Result sentence:('NN', inmate)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', walls)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'facade')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'roof')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'courtyard')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'buildings')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'brick')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'floors')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'IN', 'beneath')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'wall')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'exterior')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'RB', 'underneath')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'towers')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'roofs')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'ceilings')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'stone')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'concrete')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'facades')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'glass')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NNS', 'doors')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'VBD', 'walled')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'walls', 'of', 'glass'], 'NNS', 'NN', 'ceiling')
# NNS walls
# List 2: ['buildings', 'floors', 'towers', 'roofs', 'ceilings', 'facades', 'doors']
#
# word in concern: roofs
#
# Debugging process: (a, True, [liquid, liquid, prisoner, walls, a], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (7, glass, False, [liquid, liquid, prisoner, walls, a, glass])
# Result sentence:('DT', a)
# Result sentence:('JJ', fluid)
# Result sentence:('NN', inmate)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', roofs)
# Result sentence:('IN', of)
# Result sentence:('NN', glass)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'JJ', 'ceramic')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'VBN', 'stained')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'walls')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'plastic')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'window')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'metal')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'stone')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'piece')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'pieces')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'shards')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'wood')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'steel')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'JJ', 'stainless')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'glasses')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'brick')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'panes')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'JJ', 'wooden')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'VB', 'decorative')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NN', 'furniture')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'glass'], 'NN', 'NNS', 'bricks')
# NN glass
# List 2: ['plastic', 'window', 'metal', 'stone', 'piece', 'wood', 'steel', 'brick', 'furniture']
#
# word in concern: plastic
#
# Debugging process: (in, True, [liquid, liquid, prisoner, walls, a, glass, in], ['a', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass'])
# Random number, word in concern, is_stop_word: (6, of, True, [liquid, liquid, prisoner, walls, a, glass, in, of])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [liquid, liquid, prisoner, walls, a, glass, in, of, prisoner])
# Random number, word in concern, is_stop_word: (2, prisoner, False, [liquid, liquid, prisoner, walls, a, glass, in, of, prisoner, prisoner])
# Random number, word in concern, is_stop_word: (3, pent, False, [liquid, liquid, prisoner, walls, a, glass, in, of, prisoner, prisoner, pent])
# Result sentence:('DT', a)
# Result sentence:('JJ', fluid)
# Result sentence:('NN', inmate)
# Result sentence:('VBN', pent)
# Result sentence:('IN', in)
# Result sentence:('NNS', roofs)
# Result sentence:('IN', of)
# Result sentence:('NN', plastic)
# Does this Word2Vec model have this word?  True
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBN', 'stoked')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NNS', 'frustrations')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBN', 'pent-up')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NN', 'discontent')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NN', 'undercurrent')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBG', 'venting')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBD', 'fuelled')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBG', 'slackening')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBD', 'vented')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VB', 'groundswell')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBN', 'bubbled')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NN', 'resentment')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NN', 'restlessness')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NN', 'frustration')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBD', 'slackened')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'NNS', 'insecurities')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBN', 'fueled')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBN', 'sapped')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VBZ', 'howls')
# POS:(['a', 'fluid', 'inmate', 'pent', 'in', 'roofs', 'of', 'plastic'], 'VBN', 'VB', 'clamor')
# VBN pent
# List 2: ['stoked', 'pent-up', 'bubbled', 'fueled', 'sapped']
#
# word in concern: stoked
#
# that True
# use False
# is True
# not True
# forbidden False
# usury False
# 3
# Debugging process: (use, False, [use], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Result sentence:('DT', that)
# Result sentence:('NN', use)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', forbidden)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  True
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VBD', 'used')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VBG', 'using')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VBZ', 'uses')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'JJ', 'such')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'CC', 'or')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VB', 'make')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'NN', 'example')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VB', 'allow')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'RB', 'instead')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'MD', 'can')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'IN', 'for')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VB', 'provide')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'RB', 'rather')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'UH', 'well')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'RB', 'not')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'RB', 'either')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'TO', 'to')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'JJ', 'other')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'VBN', 'intended')
# POS:(['that', 'use', 'is', 'not', 'forbidden', 'usury'], 'NN', 'DT', 'these')
# NN use
# List 2: ['example']
#
# word in concern: example
#
# Debugging process: (not, True, [use, not], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Random number, word in concern, is_stop_word: (4, forbidden, False, [use, not, forbidden])
# Result sentence:('DT', that)
# Result sentence:('NN', example)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', forbidden)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  True
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBD', 'prohibited')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBD', 'permitted')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'RB', 'strictly')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBD', 'banned')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VB', 'forbid')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'JJ', 'sacred')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBP', 'worship')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBD', 'forbade')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBN', 'restricted')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBG', 'forbidding')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VB', 'taboo')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'NNS', 'purposes')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'VBG', 'banning')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'JJ', 'secret')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'NNS', 'forbids')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'JJ', 'religious')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'RB', 'legally')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'NN', 'religion')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'IN', 'except')
# POS:(['that', 'example', 'is', 'not', 'forbidden', 'usury'], 'VBN', 'NNS', 'rituals')
# VBN forbidden
# List 2: ['restricted']
#
# word in concern: restricted
#
# Debugging process: (forbidden, False, [use, not, forbidden, forbidden], ['that', 'use', 'is', 'not', 'forbidden', 'usury'])
# Random number, word in concern, is_stop_word: (2, is, True, [use, not, forbidden, forbidden, is])
# Random number, word in concern, is_stop_word: (3, not, True, [use, not, forbidden, forbidden, is, not])
# Random number, word in concern, is_stop_word: (2, is, True, [use, not, forbidden, forbidden, is, not, is])
# Random number, word in concern, is_stop_word: (5, usury, False, [use, not, forbidden, forbidden, is, not, is, usury])
# Result sentence:('DT', that)
# Result sentence:('NN', example)
# Result sentence:('VBZ', is)
# Result sentence:('RB', not)
# Result sentence:('VBN', restricted)
# Result sentence:('NN', usury)
# Does this Word2Vec model have this word?  True
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'antidiscrimination')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'prohibitions')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'vagrancy')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNP', 'sumptuary')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'practises')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'moneylenders')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'VBG', 'criminalizing')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'idolatry')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'strictures')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'indebtedness')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'blasphemy')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'majeste')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'halakha')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'VB', 'popery')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'VBZ', 'trumps')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'levies')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'VBD', 'legalised')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NN', 'immorality')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'VBN', 'criminalized')
# POS:(['that', 'example', 'is', 'not', 'restricted', 'usury'], 'NN', 'NNS', 'laws')
# NN usury
# List 2: ['antidiscrimination', 'vagrancy', 'idolatry', 'indebtedness', 'blasphemy', 'majeste', 'halakha', 'immorality']
#
# word in concern: antidiscrimination
#
#
#
# Results
# and only gazette to the opulent summer
# then being informed where all thy charm lies
# says back the elegant january of her foreign
# then free-spirited niggard why dost thou neglect
# a fluid inmate stoked in roofs of plastic
# that example is not restricted antidiscrimination

# %%
##### This will determine the part of speech using the process of removing and inserting a word in a sentence.
##### The copy method is used to prevent any alteration to the original sentence. Moreover, removing and inserting the word helps to
##### better determine the part of speech of a particular word rather than using the word itself to determine the part of speech.
def determiningPOSThroughSentence(Sent,W_index,tempWord):
  Sent2 = Sent.copy()
  Sent2.pop(W_index)
  Sent2.insert(W_index,tempWord)
  record = nlp(" ".join(Sent2))
  ##print(f"Substituting Sentence: {Sent2}")
  ##for token in record:
    ##print(f"Parsing the sentences with Part of Speech : {token,token.tag_}")
  pos = record[W_index].tag_
  return pos

##### This converts a sentence in list form to the one in string form. If the sentence contains the apostrophe, the space behind the apostrophe is "removed".
def turningListIntoSentence(listToBeConverted):
  newSentence = " ".join(listToBeConverted)
  if newSentence.__contains__("'"):
    newSentence = newSentence.replace(" '", "'")
  return newSentence

##### This substitutes the inital word in the sentence with another word that contains similar part of speech. It also has the GingerIT to revise the sentence,
##### preventing the method from having the syntatically incorrect sentence. Furthermore, the GingerIT is more ideal to use than the language tool python module
##### due to the fact that the GingerIT does not require downloading while the language tool python does download the jar file.
def substitutingWords(listOfWords,Sent,word_i):
  r_index = random.randint(0,len(listOfWords)-1)
  r_word = listOfWords[r_index]
  forLemmaPreviousSentence = nlp(Sent[word_i-1])[0].lemma_
  r_pos = determiningPOSThroughSentence(Sent,word_i,r_word)
  print(f"\n\nBefore: {r_word,r_index}")
  if modal_verbs.__contains__(Sent[word_i-1]) and r_pos != "VB":
    while r_pos != "VB":
      r_index = random.randint(0,len(listOfWords)-1)
      r_word = listOfWords[r_index]
      r_pos = determiningPOSThroughSentence(Sent,word_i,r_word)
      print(f"\n\nAfter: {r_word,r_index}")
  if primary_aux_verbs.count(forLemmaPreviousSentence)==1:
    if forLemmaPreviousSentence=="is" and (r_pos != "VBG" or r_pos != "VBN"):
      while r_pos != "VBG" or r_pos != "VBN":
        r_index = random.randint(0,len(listOfWords)-1)
        r_word = listOfWords[r_index]
        r_pos = determiningPOSThroughSentence(Sent,word_i,r_word)
    if forLemmaPreviousSentence=="have" and r_pos != "VBN":
      while r_pos != "VBN":
        r_index = random.randint(0,len(listOfWords)-1)
        r_word = listOfWords[r_index]
        r_pos = determiningPOSThroughSentence(Sent,word_i,r_word)
    if forLemmaPreviousSentence=="do" and r_pos != "VB":
      while(r_pos != "VB"):
        r_index = random.randint(0,len(listOfWords)-1)
        r_word = listOfWords[r_index]
        r_pos = determiningPOSThroughSentence(Sent,word_i,r_word)
  print(f"\nWord choose: {r_word}\n")
  print(f"\nOriginal sentence : {Sent}\n")
  Sent.pop(word_i)
  Sent.insert(word_i,str(r_word))
  newSentence = turningListIntoSentence(Sent)
  ginger = GingerIt()
  corrections = ginger.parse(newSentence)
  if corrections['corrections'] != None and corrections['corrections'][0]['start']==4:
    ##correctSentence = nlp(corrections['result'])
    ##if(correctSentence[word_i].is_punct):
      ##correctWord = str(correctSentence[word_i+1])
    ##else:
      ##correctWord = str(correctSentence[word_i])
    ##Sent.pop(word_i) ; Sent.insert(word_i, correctWord)
  print(f"\nFinal sentence : {Sent}\n")

##### This method will allow the list to include the lines used. It avoids repeating the same lines from the corpus.
def addingUsedLines(maxIndex,lineInConcern,corpus,listUsed):
  randomIndex = random.randint(0,maxIndex)
  lineInConcern = corpus[randomIndex]
  listUsed.append(lineInConcern)

##### This returns true if either the current part of speech matches to the target one, the current and the target ones are both verbs,
##### or the target one is considered as a noun with the current one being a present participle. It will default to false if the target part of speech
##### and the current part of speech does not match each "case statements".
def posMatch(current,target):
  if current == target:
    return True
  if current[:2]=="VB" and target[:2]=="VB":
    return True
  if target == "NN" and current == "VBG":
    return True
  return False

##### Initally, the method is created to help create a document in the list format. The method also contain an if statement for the hyphen to
##### make the two words separated by the hyphen into one. However, it might be fine for the model to create a new word like what Shakespeare did.
##def createDocList(document):
  ##doclist = list()
  ##for i in document:
    ##if(str(i) == "-"):


random.seed("Romeo and Juliet")

listOfSentences = list()
sentencesUsed = list()
maxIndexForSonnets = nGramCorpus.index(['<s>','the','end','</s>'])

for i in range(5):
  randomSonnetIndex = random.randint(0,maxIndexForSonnets)
  currentLine = nGramCorpus[randomSonnetIndex]
  sentencesUsed.append(currentLine)
  print(f"\nCurrent Line: {currentLine}\n")
  print(f"\nSentence Used: {sentencesUsed}\n")
  if(sentencesUsed.count(currentLine)>=2):
    while(sentencesUsed.count(currentLine) >= 2):
      addingUsedLines(maxIndexForSonnets,currentLine,nGramCorpus,sentencesUsed)
  if(len(currentLine) != 3):
    newLine = currentLine[1:-1]
    targetSent = " ".join(newLine)
    print(f"The target sentence: {targetSent}")
  else:
    while(len(currentLine) == 3):
      randomIndex = random.randint(0,maxIndexForSonnets)
      currentLine = nGramCorpus[randomIndex]
      ##sentencesUsed.append(currentLine)
    newLine = currentLine[1:-1]
    targetSent = " ".join(newLine)
  document = nlp(targetSent)
  docList = [str(token) for token in document]
  wordsUsed = list()
  print(f"\nSentence in concern : {document}\n")
  stopWordcounter = 0
  for word in document:
    if(word.is_stop or stop_words.count(str(word))>=1):
      stopWordcounter+=1
  nonStopWordsCounter = len(document) - stopWordcounter
  for modification in range(nonStopWordsCounter):
    maxIndexForSentence = len(document)-1
    randWordIndex = random.randint(0,maxIndexForSentence)
    targetWord = document[randWordIndex]
    wordsUsed.append(targetWord)
    print(f"\nThe list of words used: {wordsUsed}\n")
    if(targetWord.is_stop or wordsUsed.count(targetWord)>=2 or stop_words.count(str(targetWord))>=1):
      while(targetWord.is_stop or wordsUsed.count(targetWord)>=2 or stop_words.count(str(targetWord))>=1):
        randWordIndex = random.randint(0,maxIndexForSentence) ##  the method does not work for this block of code
        targetWord = document[randWordIndex]
        wordsUsed.append(targetWord)
        print(f"\nAnother list of words used: {wordsUsed}\n")
    targetPOS = targetWord.tag_
    print(f"\nTarget Word and Part of Speech : {targetWord,targetPOS}\n")
    if(anotherModel.key_to_index.get(str(targetWord))!=None):
      possibleWords = anotherModel.most_similar([str(targetWord)])
      wordStorage = list()
      for word,similarity in possibleWords:
        currentPOS = determiningPOSThroughSentence(docList,randWordIndex,word)
        print(f"\n{docList,word,currentPOS}\n")
        ######## alternate way: currentPOS = nlp(word)[0].tag_
        if posMatch(currentPOS,targetPOS):
          wordStorage.append(word)
      if(len(wordStorage)!=0):
        ##print(f"Sentence: {docList}")
        substitutingWords(wordStorage,docList,randWordIndex)
        ##print(f"New Sentence: {docList}")
  listOfSentences.append(docList)
print("\n\n\nResults")
print(listOfSentences)
# Out:
# Current Line: ['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>']
#
#
# Sentence Used: [['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>']]
#
# The target sentence: what merit do i in my self respect
#
# Sentence in concern : what merit do i in my self respect
#
#
# The list of words used: [merit]
#
#
# Target Word and Part of Speech : (merit, 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'awarded', 'VBD')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'excellence', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'achievement', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'scholarship', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'award', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'medal', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'awarding', 'VBG')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'distinction', 'NN')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'scholarships', 'NNS')
#
#
# (['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect'], 'worthy', 'JJ')
#
#
#
# Before: ('excellence', 0)
#
# Word choose: excellence
#
#
# Original sentence : ['what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect']
#
#
# Final sentence : ['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect']
#
#
# The list of words used: [merit, i]
#
#
# Another list of words used: [merit, i, in]
#
#
# Another list of words used: [merit, i, in, self]
#
#
# Target Word and Part of Speech : (self, 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'kind', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'sense', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'conscious', 'JJ')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'mind', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'life', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'rather', 'RB')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'own', 'JJ')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'sort', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], '-', 'HYPH')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect'], 'collective', 'JJ')
#
#
#
# Before: ('sense', 1)
#
# Word choose: sense
#
#
# Original sentence : ['what', 'excellence', 'do', 'i', 'in', 'my', 'self', 'respect']
#
#
# Final sentence : ['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect']
#
#
# The list of words used: [merit, i, in, self, respect]
#
#
# Target Word and Part of Speech : (respect, 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'regard', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'commitment', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'dignity', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'our', 'PRP$')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'integrity', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'wish', 'VB')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'principle', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'attitude', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'determination', 'NN')
#
#
# (['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect'], 'recognition', 'NN')
#
#
#
# Before: ('commitment', 1)
#
# Word choose: commitment
#
#
# Original sentence : ['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'respect']
#
#
# Final sentence : ['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'commitment']
#
#
# Current Line: ['<s>', 'therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made', '</s>']
#
#
# Sentence Used: [['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>'], ['<s>', 'therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made', '</s>']]
#
# The target sentence: therefore desire of perfect’st love being made
#
# Sentence in concern : therefore desire of perfect’st love being made
#
#
# The list of words used: [of]
#
#
# Another list of words used: [of, desire]
#
#
# Target Word and Part of Speech : (desire, 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'willingness', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'determination', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'wish', 'VBP')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'sense', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'commitment', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'ambition', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'hope', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'belief', 'NN')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'feelings', 'NNS')
#
#
# (['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made'], 'desires', 'NNS')
#
#
#
# Before: ('commitment', 3)
#
# Word choose: commitment
#
#
# Original sentence : ['therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made']
#
#
# Final sentence : ['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made']
#
#
# The list of words used: [of, desire, therefore]
#
#
# Another list of words used: [of, desire, therefore, therefore]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire, love]
#
#
# Target Word and Part of Speech : (love, 'NN')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'me', 'PRP')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'passion', 'NN')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'my', 'PRP$')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'life', 'NN')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'dream', 'NN')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'you', 'PRP')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'always', 'RB')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'wonder', 'NN')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'i', 'PRP')
#
#
# (['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made'], 'dreams', 'NNS')
#
#
#
# Before: ('dream', 2)
#
# Word choose: dream
#
#
# Original sentence : ['therefore', 'commitment', 'of', 'perfect’st', 'love', 'being', 'made']
#
#
# Final sentence : ['therefore', 'commitment', 'of', 'perfect’st', 'dream', 'being', 'made']
#
#
# The list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire, love, desire]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire, love, desire, therefore]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire, love, desire, therefore, being]
#
#
# Another list of words used: [of, desire, therefore, therefore, desire, made, being, of, desire, of, being, desire, love, desire, therefore, being, perfect’st]
#
#
# Target Word and Part of Speech : (perfect’st, 'NNP')
#
#
# Current Line: ['<s>', '60', '</s>']
#
#
# Sentence Used: [['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>'], ['<s>', 'therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made', '</s>'], ['<s>', '60', '</s>']]
#
#
# Sentence in concern : which this time’s pencil or my pupil pen
#
#
# The list of words used: [pencil]
#
#
# Target Word and Part of Speech : (pencil, 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'pencils', 'NNS')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'ink', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'crayon', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'pens', 'NNS')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'drawings', 'NNS')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'pen', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'watercolor', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'prints', 'NNS')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'gouache', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen'], 'erasers', 'NNS')
#
#
#
# Before: ('ink', 0)
#
# Word choose: ink
#
#
# Original sentence : ['which', 'this', 'time', '’s', 'pencil', 'or', 'my', 'pupil', 'pen']
#
#
# Final sentence : ['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen']
#
#
# The list of words used: [pencil, or]
#
#
# Another list of words used: [pencil, or, pencil]
#
#
# Another list of words used: [pencil, or, pencil, time]
#
#
# Target Word and Part of Speech : (time, 'NN')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'when', 'WRB')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'this', 'DT')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'before', 'IN')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'but', 'CC')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'only', 'RB')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'one', 'NN')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], '.', '.')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'same', 'JJ')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'first', 'JJ')
#
#
# (['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'days', 'NNS')
#
#
#
# Before: ('one', 0)
#
# Word choose: one
#
#
# Original sentence : ['which', 'this', 'time', '’s', 'ink', 'or', 'my', 'pupil', 'pen']
#
#
# Final sentence : ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen']
#
#
# The list of words used: [pencil, or, pencil, time, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil]
#
#
# Target Word and Part of Speech : (pupil, 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'teacher', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'pupils', 'NNS')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], '398', 'CD')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'tutor', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'enrollment', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'tuition', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'librarian', 'JJ')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'student', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'servant', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen'], 'dropout', 'NN')
#
#
#
# Before: ('servant', 5)
#
# Word choose: servant
#
#
# Original sentence : ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'pupil', 'pen']
#
#
# Final sentence : ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen']
#
#
# The list of words used: [pencil, or, pencil, time, my, pupil, this]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time, ’s, pencil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time, ’s, pencil, ’s]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time, ’s, pencil, ’s, pupil]
#
#
# Another list of words used: [pencil, or, pencil, time, my, pupil, this, my, this, my, or, pupil, pencil, which, or, ’s, ’s, or, my, or, time, or, or, time, ’s, or, which, ’s, time, my, my, pupil, pupil, which, time, which, which, or, time, ’s, pencil, or, time, or, time, ’s, pencil, ’s, pupil, pen]
#
#
# Target Word and Part of Speech : (pen, 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'pencil', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'ballpoint', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'pens', 'NNS')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'le', 'FW')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'ink', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'paper', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'mouse', 'VBP')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'stylus', 'NNP')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'punch', 'NN')
#
#
# (['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen'], 'pocket', 'NN')
#
#
#
# Before: ('paper', 3)
#
# Word choose: paper
#
#
# Original sentence : ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'pen']
#
#
# Final sentence : ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'paper']
#
#
# Current Line: ['<s>', 'but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace', '</s>']
#
#
# Sentence Used: [['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>'], ['<s>', 'therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made', '</s>'], ['<s>', '60', '</s>'], ['<s>', 'but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace', '</s>']]
#
# The target sentence: but is profaned if not lives in disgrace
#
# Sentence in concern : but is profaned if not lives in disgrace
#
#
# The list of words used: [not]
#
#
# Another list of words used: [not, in]
#
#
# Another list of words used: [not, in, is]
#
#
# Another list of words used: [not, in, is, but]
#
#
# Another list of words used: [not, in, is, but, lives]
#
#
# Target Word and Part of Speech : (lives, 'VBZ')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'life', 'NN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'people', 'NNS')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'living', 'VBG')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'children', 'NNS')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'lived', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'others', 'NNS')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'dead', 'JJ')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'families', 'NNS')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'dying', 'VBG')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace'], 'years', 'NNS')
#
#
#
# Before: ('living', 0)
#
# Word choose: living
#
#
# Original sentence : ['but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace']
#
#
# Final sentence : ['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace']
#
#
# The list of words used: [not, in, is, but, lives, in]
#
#
# Another list of words used: [not, in, is, but, lives, in, in]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned]
#
#
# Target Word and Part of Speech : (profaned, 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'despoiled', 'JJ')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'tyrannized', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'befouled', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'supressed', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'deprogrammed', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'superceded', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'unmarred', 'JJ')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 're-taken', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'actioned', 'VBN')
#
#
# (['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace'], 'ill-treated', 'RB')
#
#
#
# Before: ('re-taken', 5)
#
# Word choose: re-taken
#
#
# Original sentence : ['but', 'is', 'profaned', 'if', 'not', 'living', 'in', 'disgrace']
#
#
# Final sentence : ['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace']
#
#
# The list of words used: [not, in, is, but, lives, in, in, not, profaned, in]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but, not]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but, not, not]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but, not, not, is]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but, not, not, is, is]
#
#
# Another list of words used: [not, in, is, but, lives, in, in, not, profaned, in, but, not, not, is, is, disgrace]
#
#
# Target Word and Part of Speech : (disgrace, 'NN')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'shame', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'embarrassment', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'humiliation', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'betrayal', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'utter', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'disgust', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'disrepute', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'shameful', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'resigning', 'VBG')
#
#
# (['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace'], 'ridicule', 'VBG')
#
#
#
# Before: ('betrayal', 3)
#
# Word choose: betrayal
#
#
# Original sentence : ['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'disgrace']
#
#
# Final sentence : ['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'betrayal']
#
#
# Current Line: ['<s>', 'i', 'must', 'attend', 'time’s', 'leisure', 'with', 'my', 'moan', '</s>']
#
#
# Sentence Used: [['<s>', 'what', 'merit', 'do', 'i', 'in', 'my', 'self', 'respect', '</s>'], ['<s>', 'therefore', 'desire', 'of', 'perfect’st', 'love', 'being', 'made', '</s>'], ['<s>', '60', '</s>'], ['<s>', 'but', 'is', 'profaned', 'if', 'not', 'lives', 'in', 'disgrace', '</s>'], ['<s>', 'i', 'must', 'attend', 'time’s', 'leisure', 'with', 'my', 'moan', '</s>']]
#
# The target sentence: i must attend time’s leisure with my moan
#
# Sentence in concern : i must attend time’s leisure with my moan
#
#
# The list of words used: [attend]
#
#
# Target Word and Part of Speech : (attend, 'VB')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'attending', 'VBG')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'attended', 'VBD')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'participate', 'VB')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'invited', 'VBN')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'visit', 'VB')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'attends', 'VBZ')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'invitation', 'NN')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'scheduled', 'VBN')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'meeting', 'VBG')
#
#
# (['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'meet', 'VB')
#
#
#
# Before: ('meeting', 7)
#
#
# After: ('participate', 2)
#
# Word choose: participate
#
#
# Original sentence : ['i', 'must', 'attend', 'time', '’s', 'leisure', 'with', 'my', 'moan']
#
#
# Final sentence : ['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan']
#
#
# The list of words used: [attend, my]
#
#
# Another list of words used: [attend, my, with]
#
#
# Another list of words used: [attend, my, with, i]
#
#
# Another list of words used: [attend, my, with, i, my]
#
#
# Another list of words used: [attend, my, with, i, my, leisure]
#
#
# Target Word and Part of Speech : (leisure, 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'catering', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'recreation', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'recreational', 'JJ')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'hospitality', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'amenities', 'NNS')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'hotels', 'NNS')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'shopping', 'VBG')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'lodging', 'VBG')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'retailing', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan'], 'entertainment', 'NN')
#
#
#
# Before: ('recreation', 1)
#
# Word choose: recreation
#
#
# Original sentence : ['i', 'must', 'participate', 'time', '’s', 'leisure', 'with', 'my', 'moan']
#
#
# Final sentence : ['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan']
#
#
# The list of words used: [attend, my, with, i, my, leisure, time]
#
#
# Target Word and Part of Speech : (time, 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'when', 'WRB')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'this', 'DT')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'before', 'IN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'but', 'CC')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'only', 'RB')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'one', 'CD')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], '.', '.')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'same', 'JJ')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'first', 'RB')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'days', 'NNS')
#
#
# The list of words used: [attend, my, with, i, my, leisure, time, my]
#
#
# Another list of words used: [attend, my, with, i, my, leisure, time, my, must]
#
#
# Another list of words used: [attend, my, with, i, my, leisure, time, my, must, moan]
#
#
# Target Word and Part of Speech : (moan, 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'groan', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'whine', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'mutter', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'holler', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'croak', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'lamentation', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'ache', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'hum', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'sigh', 'NN')
#
#
# (['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan'], 'hoot', 'NN')
#
#
#
# Before: ('holler', 3)
#
# Word choose: holler
#
#
# Original sentence : ['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'moan']
#
#
# Final sentence : ['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'holler']
#
#
#
#
# Results
# [['what', 'excellence', 'do', 'i', 'in', 'my', 'sense', 'commitment'], ['therefore', 'commitment', 'of', 'perfect’st', 'dream', 'being', 'made'], ['which', 'this', 'one', '’s', 'ink', 'or', 'my', 'servant', 'paper'], ['but', 'is', 're-taken', 'if', 'not', 'living', 'in', 'betrayal'], ['i', 'must', 'participate', 'time', '’s', 'recreation', 'with', 'my', 'holler']]

# %%
sentence = "you must sleep before midnight"
sentenceInDocumentForm = nlp(sentence)
sentenceInDocumentListForm = [str(word) for word in sentenceInDocumentForm]
index = 2 ; goalPOS = sentenceInDocumentForm[index].tag_
wordsAndSimilarities = anotherModel.most_similar(str(sentenceInDocumentForm[index]))
listOfWords = []
for word, similarity in wordsAndSimilarities:
  currentPOS = determiningPOSThroughSentence(sentenceInDocumentListForm,index,word)
  if posMatch(currentPOS,goalPOS):
    listOfWords.append(word)
##print(nlp("Are you sleeping")[2].tag_)
##print(nlp("She sleeps")[1].tag_)
random.seed(5)
substitutingWords(listOfWords,sentenceInDocumentListForm,index)

ginger = GingerIt()
corrections = ginger.parse(" ".join(sentenceInDocumentListForm))
if(corrections['corrections'] != None):
  correctDocument = nlp(corrections['result'])
  wordToReplace = correctDocument[index]
  sentenceInDocumentListForm.pop(2) ; sentenceInDocumentListForm.insert(2,wordToReplace)
print(sentenceInDocumentListForm)
# Out:
# Before: ('slept', 4)
#
# Word choose: slept
#
#
# Original sentence : ['you', 'must', 'sleep', 'before', 'midnight']
#
#
# Final sentence : ['you', 'must', 'slept', 'before', 'midnight']
#
# ['you', 'must', sleep, 'before', 'midnight']

# %%
sentence = "Laura 's novels are amazing"
###if sentence.__contains__(" '"):
  ##sentence = sentence.replace(" '","'")
##print(sentence)
##docList = [token.text for token in nlp(sentence)]
##for i in docList:
  ##print(i,isinstance(i,str))
# Out:
# Laura True
# 's True
# novels True
# are True
# amazing True

# %%
### This method classifies the part of speech of a particular word
### through the process of deleting the word that needs to be replaced and adding the new word to
### determine the part of speech.
def findingPartOfSpeech(docSentence,word,index):
  docSentence.pop(index)
  docSentence.insert(index,word)
  new_Sentence = " ".join(docSentence)
  new_document = nlp(new_Sentence)
  posTag= new_document[index].tag_
  return posTag

### This method will randomly pick a word from the word list and see if
### the word has the same part of speech like the specified one.
def evaluatePOS(sentence,wordList,partOfSpeech,rPOS,rWord,doc_index):
  while(rPOS != partOfSpeech):
    rIndex = random.randint(0,len(wordList)-1)
    rWord = wordList[rIndex]
    rPOS = findingPartOfSpeech(sentence,rWord,doc_index)
    print(f"Current random word : {rIndex,rWord,rPOS}")
  return rWord

### This method is similar to the previous method. However, the boolean statements are
### different to accomondate Python's inability to do polymorphism (same methods with different parameters).
def evaluatePOS2(sentence,wordList,partOfSpeech1,partOfSpeech2,rPOS,rWord,doc_index):
  while(rPOS != partOfSpeech1 or rPOS != partOfSpeech2):
    randIndex = random.randint(0, len(wordList)-1)
    rWord = wordList[randIndex]
    rPOS = findingPartOfSpeech(sentence,rWord,doc_index)
    print(f"Current random word : {randIndex,rWord,rPOS}")
  return rWord

### This is another similar model with the 'equals boolean' to determine if the particular part of speech
### is similar to the other part of speech specified.
def evaluatePOS3(sentence,wordList,partOfSpeech,rPOS,rWord,doc_index):
  while(rPOS==partOfSpeech):
    rIndex = random.randint(0,len(wordList)-1)
    rWord = wordList[rIndex]
    rPOS = findingPartOfSpeech(sentence,rWord,doc_index)
    print(f"Current random word : {rIndex,rWord,rPOS}")
  return rWord

### This method will convert the list object into a sentence (string). If the newly-converted sentence
### contains an apostrophe, it will merge the apostrophe to the previous word.
def convertListToSentence(wordList):
  convertedSentence = " ".join(wordList)
  if convertedSentence.__contains__("'"):
    convertedSentence = convertedSentence.replace(" '","'")
  return convertedSentence

### The method involves picking a random index. The random index is then used to obtain the random word.
### The lemma of the previous word helps to determine if the word (in verb form) is grammarically incorrect.
### If it is, the word will be replace by another one with accurate rendering.
### The GingerIt software helps to check if the sentence is grammarically correct if the pos-tagger fails to catagorize the part of speech.
### The recommendation for using the method is to make sure that the document in the list format is the Sent parameter.
def substitutingWords(listOfWords,Sent,doc_i):
  r_index = random.randint(0,len(listOfWords)-1)
  r_word = listOfWords[r_index]
  sentence2 = Sent.copy()
  document = nlp(" ".join(sentence2))
  documentList = [str(token) for token in document]
  if doc_i != 0 : forLemmaPreviousSentence = document[doc_i-1].lemma_
  r_pos = findingPartOfSpeech(documentList,r_word,doc_i)
  print(f"\nThe previous word (lemma): {forLemmaPreviousSentence}")
  print(f"\n\nBefore: {r_word,r_index,r_pos}")
  if modal_verbs.__contains__(documentList[doc_i-1]) and r_pos != "VB":
    r_word = evaluatePOS(documentList, listOfWords, "VB", r_pos, r_word, doc_i)
  if primary_aux_verbs.count(forLemmaPreviousSentence)==1:
    if forLemmaPreviousSentence=="is" and (r_pos != "VBG" or r_pos != "VBN"):
      r_word = evaluatePOS2(documentList,listOfWords,"VBG","VBN",r_word,doc_i)
    if forLemmaPreviousSentence=="have" and r_pos != "VBN":
      r_word = evaluatePOS(documentList,listOfWords,"VBN",r_pos,r_word,doc_i)
    if forLemmaPreviousSentence=="do" and r_pos != "VB":
      r_word = evaluatePOS(documentList, listOfWords, "VB", r_pos, r_word, doc_i)
  if document[doc_i-1].tag_[:2] == "NN" and r_pos == "VBG":
    r_word = evaluatePOS3(documentList,listOfWords,"VBG",r_pos,r_word,doc_i)
  print(f"\nWord choose: {r_word}\n")
  print(f"\nOriginal sentence : {Sent}\n")
  documentList.pop(doc_i)
  documentList.insert(doc_i,r_word)
  newSentence = convertListToSentence(documentList)
  ginger = GingerIt()
  corrections = ginger.parse(newSentence)
  if corrections['corrections'] != None:
    correctSentence = nlp(corrections['result'])
    if(correctSentence[doc_i].is_punct):
      wordToCorrect = str(correctSentence[doc_i+1])
    else:
      wordToCorrect = str(correctSentence[doc_i])
    documentList.pop(doc_i) ; documentList.insert(doc_i,wordToCorrect)
  newSentence = convertListToSentence(documentList)
  print(f"\nFinal sentence : {newSentence}\n")

random.seed(3)
particularSentence = "tracy's miniature sack must contain some candy"
particularSentence2 = [str(token) for token in nlp(particularSentence)]
listOFWORDS = ['damaged','ruined','ripped','rip','ruin','have']
doc_index = 5 ; previous_word = particularSentence2[doc_index-1]
word = particularSentence2[doc_index]
##print(anotherModel.most_similar(word))
previous_lemma = nlp(previous_word)[0].lemma_
word_pos = nlp(particularSentence2[doc_index])[0].tag_
substitutingWords(listOFWORDS,particularSentence2,doc_index)
##previous_lemma=="do" and word_pos != "VB"
# Out:
# The previous word (lemma): must
#
#
# Before: ('ruined', 1, 'VBN')
# Current random word : (4, 'ruin', 'VB')
#
# Word choose: ruin
#
#
# Original sentence : ['tracy', "'s", 'miniature', 'sack', 'must', 'contain', 'some', 'candy']
#
#
# Final sentence : tracy's miniature sack must ruin some candy

# %%
testDocument1 = nlp("you must slept")
testDocument2 = nlp("you must tell a joke")

print(f"Test Document 1 : {testDocument1[2].tag_}")
print(f"Test Document 2 : {testDocument2[2].tag_}")

for i in testDocument2:
  print(isinstance(i,str))
# Out:
# Test Document 1 : VB
# Test Document 2 : VB
# False
# False
# False
# False
# False

# %%
x=['<s>',"larry's",'spaghetti','is','amazing','like','my',"grandma's",'sandwich','and',"sally's",'savory','tacos','</s>']
y=['<s>',"larry's",'spaghetti','</s>']
wordsInList = x[1:-1].copy()
sentence = " ".join(wordsInList)
##sentence = "before midnight, we played games."
nlp = spacy.load("en_core_web_sm")

doc = nlp(sentence)
word = doc[0]
counter = 0
list1 = list()
for w in doc:
  print(f"Word: {w,w.is_stop}")
  if w.is_stop:
    counter+=1
print(f"Number of non-stopwords: {len(doc)-counter} Counter: {counter}")

print(f"Is '-' a stop word: {nlp('-')[0].is_stop}")

print(f"{anotherModel.most_similar(['self-discipline'])}")

##print(f"{nltk.pos_tag(['then','beauteous','niggard','why','dost','thou','abuse'])}")

##print(anotherModel.key_to_index.get("th'vein")==None)

testDoc = nlp("then beauteous niggard why dost thou abuse")

testDoc[-1].tag_ ; l = list()

for i in range(2):
  l.append(y)
l.count(y)

array = []
steak = nlp("my fire-smoked steak")
for i in steak:
  array.append(i)
##if(array.__contains__(nlp("-"))):
  ##index = array.index("-")
  ##newWord = nlp("".join([]))

document = nlp("you have napped")
print(document[2].dep_)
#if(len(doc)>len(wordsInList)):
#  positionDifference = len(doc)-len(wordsInList)
#  index = 3
#  print(wordsInList[index])
#  print(doc[index+1])
#positionDifference
nlp("is controlled")[1].tag_
# Out:
# Word: (larry, False)
# Word: ('s, True)
# Word: (spaghetti, False)
# Word: (is, True)
# Word: (amazing, False)
# Word: (like, False)
# Word: (my, True)
# Word: (grandma, False)
# Word: ('s, True)
# Word: (sandwich, False)
# Word: (and, True)
# Word: (sally, False)
# Word: ('s, True)
# Word: (savory, False)
# Word: (tacos, False)
# Number of non-stopwords: 9 Counter: 6
# Is '-' a stop word: False
# [('self-reliance', 0.7289815545082092), ('self-confidence', 0.7239317297935486), ('self-denial', 0.6930438280105591), ('self-control', 0.6915157437324524), ('self-restraint', 0.6889591217041016), ('innovativeness', 0.6723949313163757), ('self-knowledge', 0.6351141929626465), ('open-mindedness', 0.62314772605896), ('unselfishness', 0.6142915487289429), ('straightforwardness', 0.6129526495933533)]
# ROOT
# 'VBN'

# %%
random.seed("sonnet")

##nltk.pos_tag(['laughter and tragedy'])[0]

sentence = ['<s>','the','brown','fox','ate','some','chicken','</s>']   ##nGramCorpus[5]
tempSentence = sentence[1:-1].copy()
print(nltk.pos_tag(tempSentence))

num = 3 ##random.randint(1,len(tempSentence)-2)
target_pos = nltk.pos_tag(tempSentence)[num][1]
word = tempSentence.pop(num)
list_of_possible_w = anotherModel.most_similar([word]) ##  It seems that the corpus model might be the most suitable model

array = list()

print("\nUsing the word-insert method to determine POS\n")

for w,s in list_of_possible_w:
  tempSentence.insert(num,w)
  current_pos = nltk.pos_tag(tempSentence)[num][1]
  print(nltk.pos_tag(tempSentence))
  tempSentence.pop(num)
  if (current_pos == target_pos):
    array.append(w)
    ##print(f"{current_pos},{w}")
tempSentence.insert(num,word) ##  making sure that the second sentence has the verb "ate"
print()

print(f"Word in concern: {word},{target_pos}")
print(f"Result array: {array}")
##print(f"List of likely words: {list_of_possible_w}")

##nltk.pos_tag(sentence)


######################################################
print("\nUsing only word to determine POS\n")
num2 = 3
tar_word = nltk.pos_tag(tempSentence)[num2][0]
tar_pos = nltk.pos_tag(tempSentence)[num2][1]
words_with_high_sim = anotherModel.most_similar([tar_word])
list_of_words = []
for word, similarity in words_with_high_sim:
  POS_in_concern = nltk.pos_tag([word])[0][1]
  print(f"{word} {POS_in_concern}")
  if(POS_in_concern==tar_pos):
    list_of_words.append(word)
print()
print(f"Result array: {list_of_words}")
print(f"{tar_word}, {tar_pos}")
# Out:
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('ate', 'VB'), ('some', 'DT'), ('chicken', 'NN')]
#
# Using the word-insert method to determine POS
#
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('eaten', 'VB'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('eat', 'VB'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('eating', 'VBG'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('eats', 'VBZ'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('cooked', 'VBD'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('meal', 'VB'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('drank', 'VBD'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('hamburgers', 'NNS'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('chicken', 'VB'), ('some', 'DT'), ('chicken', 'NN')]
# [('the', 'DT'), ('brown', 'JJ'), ('fox', 'NN'), ('vegetables', 'VBZ'), ('some', 'DT'), ('chicken', 'NN')]
#
# Word in concern: ate,VB
# Result array: ['eaten', 'eat', 'meal', 'chicken']
#
# Using only word to determine POS
#
# eaten VB
# eat NN
# eating VBG
# eats NNS
# cooked NNS
# meal NN
# drank NN
# hamburgers NNS
# chicken NN
# vegetables NNS
#
# Result array: ['eaten']
# ate, VB

# %%
#### This method converts the n-gram into a text file in JSON format.
def toJson(fileName,nGram):   ## based on code of the json
  j = json.dumps(nGram,indent=2,sort_keys=True)
  with open(fileName,'w',encoding='UTF-8 SIG') as file:
    file.write(j)

toJson('trigramJSON.txt',trigram)

# %%
shakespeareModel = gensim.models.Word2Vec(nGramCorpus)

# %%
shakespeareVec = shakespeareModel.wv  ##  one participant in the stack overflow recommends using the keyed vectors to access the necessary methods to observe vectors
print(shakespeareVec.get_vector('king'))
shakespeareVec.most_similar(positive=['king','woman'],negative=['man']) ##  might need to improve the method of creating the model. Gives unrelated words.
# Out:
# [-1.4896965   0.1447495   0.0036604   0.25758362  0.49845004 -0.46043837
#   0.21552297  0.20915282 -0.76130944 -0.1171189  -1.0549004  -1.7121533
#  -1.3556584  -0.05107461 -0.72724795 -0.13814832  0.36822715  0.3621659
#   0.3265515  -0.73169017  0.70435935 -0.07982887  1.5312544  -0.25616178
#   0.7680597  -0.28350765 -1.0291958   1.1405867   0.59878516 -0.7911796
#   0.77788746 -0.02804234  0.6727259  -0.8300943  -0.4491143   0.7938127
#  -0.48172775 -0.60219496 -0.8509416  -0.8016355  -0.80425304 -0.12479208
#  -0.7453309  -0.21951714  0.0509445   0.1836334  -1.0511628  -0.71461177
#  -0.7396245  -0.02729492  0.41317728 -0.8457642  -1.1995511   0.50138617
#  -0.3878732  -1.2224385   1.155316   -0.98782855 -0.442695    1.5800965
#   0.0377332  -0.7573597   1.4008025  -1.3585383  -0.36837465  1.6977412
#  -0.26921254  0.26928177  0.16641732 -0.9248975  -0.34953982  1.9365983
#   0.4783118   0.6561674   1.0384973  -1.4027077   0.32118008 -0.12025905
#  -0.25305822  0.16531774 -0.9188779   0.17844805 -0.19319007 -0.38634688
#  -0.11235199 -1.1332525   1.2142718  -0.02494371 -1.0897524   0.1331136
#   0.28899366  1.0246004   0.663902   -0.3808663   1.552764    0.11245878
#  -1.204449   -0.23415309  0.34112117  0.28312704]
# [('prince', 0.7901446223258972),
#  ('queen', 0.748397946357727),
#  ('duke', 0.7301698923110962),
#  ('talbot', 0.716636598110199),
#  ('gaunt', 0.6881637573242188),
#  ('fifth', 0.6848716139793396),
#  ('warwick', 0.6816003322601318),
#  ('claudio', 0.6788616180419922),
#  ('dauphin', 0.6657427549362183),
#  ('plantagenet', 0.6627748012542725)]

# %%
##shakespeareVec.doesnt_match(['king','spirit','queen','nobility'])
##shakespeareVec.distance('caesar','emperor')
shakespeareVec.most_similar(positive=['greatness'])
# Out:
# [('affection', 0.9328632950782776),
#  ('privilege', 0.9308606386184692),
#  ('goodness', 0.9297807216644287),
#  ('fate', 0.9297003746032715),
#  ('folly', 0.9283994436264038),
#  ('estate', 0.926902174949646),
#  ('wound', 0.9251803755760193),
#  ('entertainment', 0.9234305024147034),
#  ('teeth', 0.9220489263534546),
#  ('complexion', 0.9183086156845093)]

# %%
shakespeareVec.get_vector('king')
# Out:
# array([-1.4896965 ,  0.1447495 ,  0.0036604 ,  0.25758362,  0.49845004,
#        -0.46043837,  0.21552297,  0.20915282, -0.76130944, -0.1171189 ,
#        -1.0549004 , -1.7121533 , -1.3556584 , -0.05107461, -0.72724795,
#        -0.13814832,  0.36822715,  0.3621659 ,  0.3265515 , -0.73169017,
#         0.70435935, -0.07982887,  1.5312544 , -0.25616178,  0.7680597 ,
#        -0.28350765, -1.0291958 ,  1.1405867 ,  0.59878516, -0.7911796 ,
#         0.77788746, -0.02804234,  0.6727259 , -0.8300943 , -0.4491143 ,
#         0.7938127 , -0.48172775, -0.60219496, -0.8509416 , -0.8016355 ,
#        -0.80425304, -0.12479208, -0.7453309 , -0.21951714,  0.0509445 ,
#         0.1836334 , -1.0511628 , -0.71461177, -0.7396245 , -0.02729492,
#         0.41317728, -0.8457642 , -1.1995511 ,  0.50138617, -0.3878732 ,
#        -1.2224385 ,  1.155316  , -0.98782855, -0.442695  ,  1.5800965 ,
#         0.0377332 , -0.7573597 ,  1.4008025 , -1.3585383 , -0.36837465,
#         1.6977412 , -0.26921254,  0.26928177,  0.16641732, -0.9248975 ,
#        -0.34953982,  1.9365983 ,  0.4783118 ,  0.6561674 ,  1.0384973 ,
#        -1.4027077 ,  0.32118008, -0.12025905, -0.25305822,  0.16531774,
#        -0.9188779 ,  0.17844805, -0.19319007, -0.38634688, -0.11235199,
#        -1.1332525 ,  1.2142718 , -0.02494371, -1.0897524 ,  0.1331136 ,
#         0.28899366,  1.0246004 ,  0.663902  , -0.3808663 ,  1.552764  ,
#         0.11245878, -1.204449  , -0.23415309,  0.34112117,  0.28312704],
#       dtype=float32)
